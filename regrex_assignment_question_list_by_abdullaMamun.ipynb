# %% [markdown]
# # Exercise on regex use pattern

# %% [markdown]
# # search pattern brand and company  if found print found else print not found

# %%
text = 'Apple is a tech brand, not a fruit'
import re
pattern_brand_company= "\b(?:Apple|brand)\b"

pattern = re.findall(r'\b(?:Apple|brand)\b', text)
if pattern == ["Apple","brand"]:
  print("Found")
else:
  print("Not found")
# Out:
# Found

# %% [markdown]
# # split the given text at @

# %%
phrase = 'the list of given email are harry@gmail.com , ron@hotmail.com'

x = re.split(r"\@", phrase)
print(x)
# Out:
# ['the list of given email are harry', 'gmail.com , ron', 'hotmail.com']

# %% [markdown]
# # Remove the punctation from the given sentence

# %%
test_phrase = 'hi! are you doing good?'
re.sub(pattern = "[^\w\s]",
        repl = "",
        string = test_phrase)
# Out:
# 'hi are you doing good'

# %% [markdown]
# # write a list of test pattern having a sequence of
# - lower case letter,
# - uppercase letter,
# - lower or upper
# - and one upper case followed by lower case

# %%
import re
test_phrase = 'Regex Is difficult to grasp in short period of time'
lower_case_letter = re.findall(r"[a-z]+", test_phrase)
print(lower_case_letter)

upper_case_letter = re.findall(r"[A-Z]+", test_phrase)
print(upper_case_letter)

lower_or_upper = re.findall(r"[a-z|A-Z]+", test_phrase)
print(lower_or_upper)

upper_folowedby_lower = re.findall(r"[A-Z]+[a-z]+", test_phrase)
print(upper_folowedby_lower)
# Out:
# ['egex', 's', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']
# ['R', 'I']
# ['Regex', 'Is', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']
# ['Regex', 'Is']

# %%
#answer


'''
['egex', 's', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']

['R', 'I']

['Regex', 'Is', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']

['Regex', 'Is']

'''
# Out:
# "\n['egex', 's', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']\n\n['R', 'I']\n\n['Regex', 'Is', 'difficult', 'to', 'grasp', 'in', 'short', 'period', 'of', 'time']\n\n['Regex', 'Is']\n\n"

# %% [markdown]
# # 5. write a list of test pattern having a sequence
# - sequence of non-digits
# - sequence of whitespace
# - sequence of non-whitespace
# - alphanumeric characters
# - non-alphanumeric

# %%
test_phrase = 'This is a string with some numbers 1233 and a symbol #hashtag'

sequence_of_non_digit = re.findall(r"\D+", test_phrase)
print(sequence_of_non_digit)

sequence_of_whitespace = re.findall(r"\s+", test_phrase)
print(sequence_of_whitespace)

sequence_of_nonwhitespace = re.findall(r"\S+", test_phrase)
print(sequence_of_nonwhitespace)

alphanumeric_character = re.findall(r"[a-zA-Z0-9_]+", test_phrase)
print(alphanumeric_character)

nonalphanumeric_character = re.findall(r"[^a-zA-Z0-9_\s]+", test_phrase)
print(nonalphanumeric_character)
# Out:
# ['This is a string with some numbers ', ' and a symbol #hashtag']
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']
# ['This', 'is', 'a', 'string', 'with', 'some', 'numbers', '1233', 'and', 'a', 'symbol', '#hashtag']
# ['This', 'is', 'a', 'string', 'with', 'some', 'numbers', '1233', 'and', 'a', 'symbol', 'hashtag']
# ['#']

# %% [markdown]
# # find the date from the given text

# %%
text="is your birthday in 12-12-1992"

match = re.search(r'(\d+-\d+-\d+)',text)
print(match.group())
# Out:
# 12-12-1992

# %% [markdown]
# # write a regrex that find anything that start with bat

# %%
text="Here comes the batman in batmobile"

startswith_bat = re.findall(r"\bbat\w+", text)
print(startswith_bat)
# Out:
# ['batman', 'batmobile']

# %% [markdown]
# # write a regrex that find all the word that end with 'at'

# %%
text="The cat in the hat sat flat on the mat."

endwith_at = re.findall(r"\w+at\b", text)
print(endwith_at)
# Out:
# ['cat', 'hat', 'sat', 'flat', 'mat']

# %% [markdown]
# # find the fistname and the last name of the person

# %%
text="First Name: Travis Last Name: Baker"
first_and_lastname = re.findall(r"(?<=:\s)[a-zA-Z]+", text)
print(first_and_lastname)
# Out:
# ['Travis', 'Baker']

# %% [markdown]
#  # find all the words with an internal o.

# %%
text="the quick brown fox over "

# %%
internal_o = re.findall(r"[a-zA-Z]*o[a-zA-Z]*", text)
internal_o
# Out:
# ['brown', 'fox', 'over']

# %% [markdown]
# # find that begin or end with o

# %%
text="quick brown fox jumps over a lazy dog"

begin_or_end = re.findall(r"(\bo\w+|o\Z)",text)
begin_or_end
# Out:
# ['over']

# %% [markdown]
# # print the answer inthe given format . hint use re.sub
# 'The quick =brown= =fox=  jumped =over= the lazy =dog= '

# %%
text="the quick brown fox jumped over the lazy dog"
replace_with = re.sub(r"\s+|$","=", text)
replace_with.capitalize()
# Out:
# 'The=quick=brown=fox=jumped=over=the=lazy=dog='

# %% [markdown]
# # get the month from the given text

# %%
text="bill gate was born in 28-10-1955 and will was born in 1-02-2000"

match = re.findall(r'\-([0-9]+)-',text)
print(match)
# Out:
# ['10', '02']

# %% [markdown]
# # splits before every o

# %%
text="python is an object oriented langugae"
split_b4o = re.split(r"\bo", text)
print(split_b4o)
# Out:
# ['python is an ', 'bject ', 'riented langugae']

# %% [markdown]
# # write a pattern that find dogs and dog

# %%
test_string = "I like dogs but my dog doesn't like me."
dog_dogs = re.findall(r"(dogs|dog)", test_string)
print(dog_dogs)
# Out:
# ['dogs', 'dog']

# %% [markdown]
# # Find all the p's and q's in the test string below.

# %%
test_string = "Quick, pizzaz shop is closing. Is this a path to queensland?"
p_q_finder = re.findall(r"(p|q)",test_string)
print(p_q_finder)
# Out:
# ['p', 'p', 'p', 'q']

# %% [markdown]
# # find everything except t in word

# %%
test_string = 'the quick brown fox jumped over the lazy dog'
everything_except_t = re.findall(r"[^t]\w+[^t]",test_string)
print(everything_except_t)
# Out:
# ['he ', 'quick ', 'brown ', 'fox ', 'jumped ', 'over ', 'he ', 'lazy ', 'dog']

# %% [markdown]
# # Find all the ^ characters in the following test sentence.

# %%
test_string = """You can match the characters not listed within the class by complementing the set. 

This is indicated by including a ^ as the first character of the class; 

^ outside a character class will simply match the ^ character. 

For example, [^5] will match any character except 5."""

finding_caret = re.findall(r'\^',test_string)
print(finding_caret)
# Out:
# ['^', '^', '^', '^']

# %% [markdown]
# # Find all three digit prices in the following test sentence.

# %%
test_string = 'The Mac book cost over $999, while the windows system can be bought for less than $550.'

finding_three_digit_price = re.findall(r'\d{3}',test_string)
print(finding_three_digit_price)
# Out:
# ['999', '550']

# %% [markdown]
# # Find all prices in the following test sentence.

# %%
test_string = """The iPhone X costs over $999, while the Android cost around $550.

Apple's MacBook Pro costs $1200, while razer blade cost $2500.

A new charger for iphone cost over $30.

Bose headphone cost around $390

"""
finding_three_price = re.findall(r'\$\d+',test_string)
print(finding_three_price)
# Out:
# ['$999', '$550', '$1200', '$2500', '$30', '$390']

# %% [markdown]
# # find all the better in the given text

# %%
robot_string = '''The Zen of Python, by Tim Peters

Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!
'''

# %%
finding_better = re.findall(r'better',robot_string)
print(finding_better)
# Out:
# ['better', 'better', 'better', 'better', 'better', 'better', 'better', 'better']

# %% [markdown]
# # find the word that start with bat and end with man

# %%
test_string = 'Batman is the best movies, batwoman never herad about it.'

bat_start_end = re.findall(r"([Bb]at\w+)", test_string)
print(bat_start_end)
# Out:
# ['Batman', 'batwoman']

# %% [markdown]
# # remove the year form the given list

# %%
str="Another You (1991-2000)"
removing_year = re.sub(r'\(\d+[-]\d+\)','',str)
print(removing_year)
# Out:
# Another You

# %% [markdown]
# # write a regex to find the url_name only

# %%
name="http://www.google-map.com" # >>>google-map output

finding_url_name = re.findall(r'\w+[?-]\w+',name)
print(finding_url_name)
# Out:
# ['google-map']

# %% [markdown]
# # find the following condition from the below list
# - use regrex  to find the size of the screen
# - use regrex to find the type of laptop eg: notebook
# - find the type of display
# - find the disk capacity size

# %%
doc=["Lenovo IdeaPad S145 Laptop 39,6 cm (15,6 Zoll, 1920x1080, FHD, matt) Slim Notebook (Intel Pentium N5000, 8 GB RAM, 512 GB SSD, Intel UHD-Grafik 605, Windows 10 Home) schwarz",
"HP Notebook (15,6 Zoll), HD Display, AMD A4 2 x 2.50 GHz, 8 GB RAM, 256 GB SSD, HDMI, AMD R3 Grafik, Webcam, Windows 10 Pro",
'Neu Apple MacBook Air (13", 1,1 GHz dual-core Intel Core i3 Prozessor der 10. Generation, 8 GB RAM, 256 GB) - Silber',
'Lenovo (17,3 Zoll) Notebook (Intel Pentium 5405U 4-Thread CPU, 2.30 GHz, 8GB DDR4 RAM, 256GB SSD, 1000GB, DVD±RW, Intel HD, HDMI, Webcam, Bluetooth, USB3.0, WLAN, Win 10 Prof. 64, MS Office) #6477'
]

# %%
print("notebook 1 : ", doc[0])
# Out:
# notebook 1 :  Lenovo IdeaPad S145 Laptop 39,6 cm (15,6 Zoll, 1920x1080, FHD, matt) Slim Notebook (Intel Pentium N5000, 8 GB RAM, 512 GB SSD, Intel UHD-Grafik 605, Windows 10 Home) schwarz

# %%
print("notebook 2 : ", doc[1])
print("\n")
print("notebook 3 : ", doc[2])
print("\n")
print("notebook 4 : ", doc[3])
# Out:
# notebook 2 :  HP Notebook (15,6 Zoll), HD Display, AMD A4 2 x 2.50 GHz, 8 GB RAM, 256 GB SSD, HDMI, AMD R3 Grafik, Webcam, Windows 10 Pro
#
#
# notebook 3 :  Neu Apple MacBook Air (13", 1,1 GHz dual-core Intel Core i3 Prozessor der 10. Generation, 8 GB RAM, 256 GB) - Silber
#
#
# notebook 4 :  Lenovo (17,3 Zoll) Notebook (Intel Pentium 5405U 4-Thread CPU, 2.30 GHz, 8GB DDR4 RAM, 256GB SSD, 1000GB, DVD±RW, Intel HD, HDMI, Webcam, Bluetooth, USB3.0, WLAN, Win 10 Prof. 64, MS Office) #6477

# %%
size_of_the_screen = list(map(lambda x : re.findall(r'\d+[,]\d\sZoll|\d+["]',x),doc))
print(size_of_the_screen)
# Out:
# [['15,6 Zoll'], ['15,6 Zoll'], ['13"'], ['17,3 Zoll']]

# %%
type_of_laptop = doc[0][0:26], doc[1][0:11], doc[2][0:21], doc[3][0:27]
type_of_laptop
# Out:
# ('Lenovo IdeaPad S145 Laptop',
#  'HP Notebook',
#  'Neu Apple MacBook Air',
#  'Lenovo (17,3 Zoll) Notebook')

# %%
type_of_display = list(map(lambda x: re.findall(r'(HD|FHD)',x),doc))
type_of_display
# Out:
# [['FHD', 'HD'], ['HD', 'HD'], [], ['HD', 'HD']]

# %%
# Dipros solution
ans = lambda x: {'screen_size' : re.search(r"(?!\()\S+((?=\sZoll\b)|(?=\"))", x).group(),
                'type_laptop' : re.search(r"\w+(b|B)ook", x).group(),
                'type_display' : re.search(r"\w*HD",x).group() if re.search(r"\w*HD",x)!=None else None,
                'disk_capacity' : re.findall(r"(\d{2,4}\s*GB\b)",x)}

print(list(map(ans,doc)))
# Out:
# [{'screen_size': '15,6', 'type_laptop': 'Notebook', 'type_display': 'FHD', 'disk_capacity': ['512 GB']}, {'screen_size': '15,6', 'type_laptop': 'Notebook', 'type_display': 'HD', 'disk_capacity': ['256 GB']}, {'screen_size': '13', 'type_laptop': 'MacBook', 'type_display': None, 'disk_capacity': ['256 GB']}, {'screen_size': '17,3', 'type_laptop': 'Notebook', 'type_display': 'HD', 'disk_capacity': ['256GB', '1000GB']}]

# %% [markdown]
# # write a expressoion to get a name and phonenumber for the person whose name start with j and end with neu

# %%
phones="""Earn Cash For Your Teeth 555-6312
Family Therapy Center 555-HUGS
Homer Jay Simpson (Plow King episode) 555-3223
Homer Jay Simpson (work) 555-7334
Jack Neu 555-7666
Jeb Neu 555-5543
Jennifer Neu 555-3652
Ken Neu 555-8752
Lionel Putz 555-5299
MAD Magazine 555-8628
Marital Street Hotline 555-1680
Marvin Monroe 555-3700
Marvin Monroe's radio therapy show 555-PAIN
Moe Szyslak (phone number spells SMITHERS) 7648-4377
Moe Szyslak 555-0000
Moe's Tavern 555-1239
Mr. Plow 555-3226"""

finding_name = re.findall(r'[J]\w+ Neu \d+[-]\d+',phones)
print(finding_name)
# Out:
# ['Jack Neu 555-7666', 'Jeb Neu 555-5543', 'Jennifer Neu 555-3652']

# %% [markdown]
# # from  the given input find the  month either feb or feburary and the year
# - output[('February', '2011'), ('Feb', '2012'), ('Feb', '2016')]

# %%
year=" February 2011 and Feb 2012 was the worst year the Feb 2016"
out = re.findall(r'[F|f]\w+\s\d+',year)
print(out)
# Out:
# ['February 2011', 'Feb 2012', 'Feb 2016']

# %% [markdown]
# # from the given  tag get the text as:
# ```
# composer:  steven wilson
# author:  wilson
# city:  kingston
# band: porcupine tree
# song: Yellow Hedgerow Dreamscape
# ```

# %%
a="""<composer> steven wilson </composer>
    <author> wilson </author>
    <city> kingston </city>
    <band>porcupine tree</band>
    <song>Yellow Hedgerow Dreamscape</song>"""

# %%
getting_first = re.findall(r'(?<=<)[a-z]\w+',a)
name = re.findall(r'(?<=>\s)\w+\s\w+|(?<=>\s)\w+|(?<=>)\w+\s?\w+\s?\w+',a)
output = [((getting_first[x])+': '+name[x]) for x in range(len(getting_first))]
print(output)
# Out:
# ['composer: steven wilson', 'author: wilson', 'city: kingston', 'band: porcupine tree', 'song: Yellow Hedgerow Dreamscape']

# %% [markdown]
# # from the given list of string print get the output as
# ```
# llison Neu 99-12332-213123
# Lionel Messi 123-5435-453534
# Mark zukerberg 555-5299-32
# Homer Jay Simpson 55-7334-324
# ```
# using regex
# hint: user a grouping from re.search method

# %%
list1 = ["99-12332-213123 Neu, Allison", 
     " 123-5435-453534 Messi, Lionel", 
     "555-5299-32 zukerberg, Mark",
     "55-7334-324 Simpson, Homer Jay"]
list_of_last_name = list(map(lambda x: re.findall(r'\w+(?=,)',x),list1))
list_of_first_name = list(map(lambda x: re.findall(r'(?<=, )\w+\s\w+|(?<=, )\w+',x),list1))
list_of_num = list(map(lambda x: re.findall(r'\d+[-]\d+[-]\d+(?= )',x),list1))
output = [list_of_first_name[x][0]+' '+list_of_last_name[x][0]+' '+list_of_num[x][0] for x in range(len(list_of_first_name))]

for i in output:
    print(i)
# Out:
# Allison Neu 99-12332-213123
# Lionel Messi 123-5435-453534
# Mark zukerberg 555-5299-32
# Homer Jay Simpson 55-7334-324

# %% [markdown]
# # from the given string use a named capturing group to get the the hour,min,sec .

# %%
s = "Sun Oct 14 12:48:13 CEST 2021"
time = re.findall(r"(\d+:\d+:\d+)", s)
time
# Out:
# ['12:48:13']

# %% [markdown]
# # from the given string get the cities name only and append it in a list

# %%
cities="""1.  Berlin          3.382.169 Berlin
2.  Hamburg         1.715.392 Hamburg
3.  München         1.210.223 Bayern
4.  Köln              962.884 Nordrhein-Westfalen
5.  Frankfurt am Main 646.550 Hessen
6.  Essen             595.243 Nordrhein-Westfalen
7.  Dortmund          588.994 Nordrhein-Westfalen
8.  Stuttgart         583.874 Baden-Württemberg
9.  Düsseldorf        569.364 Nordrhein-Westfalen
10. Bremen            539.403 Bremen
11. Hannover          515.001 Niedersachsen
12. Duisburg          514.915 Nordrhein-Westfalen
13. Leipzig           493.208 Sachsen
14. Nürnberg          488.400 Bayern
15. Dresden           477.807 Sachsen
16. Bochum            391.147 Nordrhein-Westfalen
17. Wuppertal         366.434 Nordrhein-Westfalen
18. Bielefeld         321.758 Nordrhein-Westfalen
19. Mannheim          306.729 Baden-Württemberg"""

# %%
cities_name= re.findall(r'\s+([\w\s-]+\w)\s+', cities)
output=sorted(list(set(cities_name)))
for i in output:
    print(i)
# Out:
# Baden-Württemberg
# Bayern
# Berlin
# Bielefeld
# Bochum
# Bremen
# Dortmund
# Dresden
# Duisburg
# Düsseldorf
# Essen
# Frankfurt am Main
# Hamburg
# Hannover
# Hessen
# Köln
# Leipzig
# Mannheim
# München
# Niedersachsen
# Nordrhein-Westfalen
# Nürnberg
# Sachsen
# Stuttgart
# Wuppertal

# %% [markdown]
# # open a file code.txt and search for all the city and  post code in the a text file .
#  - use context manager (with ) keyword to open file
#  - since the same city will have a many postal code
#  - create a dictionary where it will add all the postal code of the same city eg:
#  ````
# ' Aachen': {' 52070 ', ' 52074 ', ' 52066 ', ' 52072 ', ' 52064 ', ' 52068 ', ' 52080 ', ' 52076 ', ' 52078 ', ' 52062 '},
# ```
# output: use the question above to get the top 19 cities postal code only.

# %%
with open('code.txt') as f:
    data = f.read()
cit_postal = re.findall(r"\d+\s(?P<city>\D+)\s(?P<postal>\d+)", data)
cities_dict={}
for i,j in cit_postal:
    if i not in cities_dict.keys():
        cities_dict.update({i:[j]})
    else:
        cities_dict[i].append(j)

# %%
i = 1
for city in cities_dict:
    print(i,".", "City :",city, "\n Postal Codes: \n", cities_dict[city])
    i+=1
# Out:
# 1 . City : Aach
#  Postal Codes:
#  ['78267', '54298']
# 2 . City : Aachen
#  Postal Codes:
#  ['52062', '52064', '52066', '52068', '52070', '52072', '52074', '52076', '52078', '52080']
# 3 . City : Aalen
#  Postal Codes:
#  ['73430', '73431', '73432', '73433', '73434']
# 4 . City : Aarbergen
#  Postal Codes:
#  ['65326']
# 5 . City : Aasbüttel
#  Postal Codes:
#  ['25560']
# 6 . City : Abenberg
#  Postal Codes:
#  ['91183']
# 7 . City : Abensberg
#  Postal Codes:
#  ['93326']
# 8 . City : Abentheuer
#  Postal Codes:
#  ['55767']
# 9 . City : Absberg
#  Postal Codes:
#  ['91720']
# 10 . City : Abstatt
#  Postal Codes:
#  ['74232']
# 11 . City : Abtsbessingen
#  Postal Codes:
#  ['99713']
# 12 . City : Abtsgmünd
#  Postal Codes:
#  ['73453']
# 13 . City : Abtsteinach
#  Postal Codes:
#  ['69518']
# 14 . City : Abtswind
#  Postal Codes:
#  ['97355']
# 15 . City : Abtweiler
#  Postal Codes:
#  ['55568']
# 16 . City : Achberg
#  Postal Codes:
#  ['88147']
# 17 . City : Achern
#  Postal Codes:
#  ['77855']
# 18 . City : Achim
#  Postal Codes:
#  ['28832']
# 19 . City : Achslach
#  Postal Codes:
#  ['94250']
# 20 . City : Achstetten
#  Postal Codes:
#  ['88480']
# 21 . City : Acht
#  Postal Codes:
#  ['56729']
# 22 . City : Achtelsbach
#  Postal Codes:
#  ['55767']
# 23 . City : Achterwehr
#  Postal Codes:
#  ['24239']
# 24 . City : Achtrup
#  Postal Codes:
#  ['25917']
# 25 . City : Adelberg
#  Postal Codes:
#  ['73099']
# 26 . City : Adelebsen
#  Postal Codes:
#  ['37139']
# 27 . City : Adelheidsdorf
#  Postal Codes:
#  ['29352']
# 28 . City : Adelmannsfelden
#  Postal Codes:
#  ['73486']
# 29 . City : Adelschlag
#  Postal Codes:
#  ['85111']
# 30 . City : Adelsdorf
#  Postal Codes:
#  ['91325']
# 31 . City : Adelsheim
#  Postal Codes:
#  ['74740']
# 32 . City : Adelshofen
#  Postal Codes:
#  ['91587', '82276']
# 33 . City : Adelsried
#  Postal Codes:
#  ['86477']
# 34 . City : Adelzhausen
#  Postal Codes:
#  ['86559']
# 35 . City : Adenau
#  Postal Codes:
#  ['53518']
# 36 . City : Adenbach
#  Postal Codes:
#  ['67742']
# 37 . City : Adenbüttel
#  Postal Codes:
#  ['38528']
# 38 . City : Adendorf
#  Postal Codes:
#  ['21365']
# 39 . City : Adlkofen
#  Postal Codes:
#  ['84166']
# 40 . City : Admannshagen-Bargeshagen
#  Postal Codes:
#  ['18211']
# 41 . City : Adorf
#  Postal Codes:
#  ['8626']
# 42 . City : Aebtissinwisch
#  Postal Codes:
#  ['25572']
# 43 . City : Aerzen
#  Postal Codes:
#  ['31855']
# 44 . City : Affalterbach
#  Postal Codes:
#  ['71563']
# 45 . City : Affing
#  Postal Codes:
#  ['86444']
# 46 . City : Affinghausen
#  Postal Codes:
#  ['27257']
# 47 . City : Affler
#  Postal Codes:
#  ['54689']
# 48 . City : Agathenburg
#  Postal Codes:
#  ['21684']
# 49 . City : Agethorst
#  Postal Codes:
#  ['25560']
# 50 . City : Aglasterhausen
#  Postal Codes:
#  ['74858']
# 51 . City : Aham
#  Postal Codes:
#  ['84168']
# 52 . City : Ahaus
#  Postal Codes:
#  ['48683']
# 53 . City : Ahausen
#  Postal Codes:
#  ['27367']
# 54 . City : Ahlbeck
#  Postal Codes:
#  ['17375']
# 55 . City : Ahlden
#  Postal Codes:
#  ['29693']
# 56 . City : Ahlefeld-Bistensee
#  Postal Codes:
#  ['24358']
# 57 . City : Ahlen
#  Postal Codes:
#  ['59227', '59229']
# 58 . City : Ahlerstedt
#  Postal Codes:
#  ['21702']
# 59 . City : Ahlsdorf
#  Postal Codes:
#  ['6313']
# 60 . City : Ahlstädt
#  Postal Codes:
#  ['98553']
# 61 . City : Ahnatal
#  Postal Codes:
#  ['34292']
# 62 . City : Ahneby
#  Postal Codes:
#  ['24996']
# 63 . City : Ahnsbeck
#  Postal Codes:
#  ['29353']
# 64 . City : Ahnsen
#  Postal Codes:
#  ['31708']
# 65 . City : Aholfing
#  Postal Codes:
#  ['94345']
# 66 . City : Aholming
#  Postal Codes:
#  ['94527']
# 67 . City : Ahorn
#  Postal Codes:
#  ['74744', '96482']
# 68 . City : Ahorntal
#  Postal Codes:
#  ['95491']
# 69 . City : Ahrbrück
#  Postal Codes:
#  ['53506']
# 70 . City : Ahrensbök
#  Postal Codes:
#  ['23623']
# 71 . City : Ahrensburg
#  Postal Codes:
#  ['22926']
# 72 . City : Ahrensfelde
#  Postal Codes:
#  ['16356']
# 73 . City : Ahrenshagen-Daskow
#  Postal Codes:
#  ['18320']
# 74 . City : Ahrenshöft
#  Postal Codes:
#  ['25853']
# 75 . City : Ahrenshoop
#  Postal Codes:
#  ['18347']
# 76 . City : Ahrenviöl
#  Postal Codes:
#  ['25885']
# 77 . City : Ahrenviölfeld
#  Postal Codes:
#  ['24896', '25885']
# 78 . City : Aichach
#  Postal Codes:
#  ['86551']
# 79 . City : Aicha vorm Wald
#  Postal Codes:
#  ['94529']
# 80 . City : Aichelberg
#  Postal Codes:
#  ['73101']
# 81 . City : Aichen
#  Postal Codes:
#  ['86479']
# 82 . City : Aichhalden
#  Postal Codes:
#  ['78733']
# 83 . City : Aichstetten
#  Postal Codes:
#  ['88317']
# 84 . City : Aichtal
#  Postal Codes:
#  ['72631']
# 85 . City : Aichwald
#  Postal Codes:
#  ['73773']
# 86 . City : Aidenbach
#  Postal Codes:
#  ['94501']
# 87 . City : Aidhausen
#  Postal Codes:
#  ['97491']
# 88 . City : Aidlingen
#  Postal Codes:
#  ['71134']
# 89 . City : Aiglsbach
#  Postal Codes:
#  ['84089']
# 90 . City : Ailertchen
#  Postal Codes:
#  ['56459']
# 91 . City : Aindling
#  Postal Codes:
#  ['86447']
# 92 . City : Ainring
#  Postal Codes:
#  ['83404']
# 93 . City : Aislingen
#  Postal Codes:
#  ['89344']
# 94 . City : Aiterhofen
#  Postal Codes:
#  ['94330']
# 95 . City : Aitern
#  Postal Codes:
#  ['79677']
# 96 . City : Aitrach
#  Postal Codes:
#  ['88319']
# 97 . City : Aitrang
#  Postal Codes:
#  ['87648']
# 98 . City : Aken (Elbe)
#  Postal Codes:
#  ['6385', '6386']
# 99 . City : Aland
#  Postal Codes:
#  ['39615']
# 100 . City : Albaching
#  Postal Codes:
#  ['83544']
# 101 . City : Albbruck
#  Postal Codes:
#  ['79774']
# 102 . City : Albersdorf
#  Postal Codes:
#  ['25767', '7646']
# 103 . City : Albershausen
#  Postal Codes:
#  ['73095']
# 104 . City : Albersweiler
#  Postal Codes:
#  ['76857']
# 105 . City : Albertshofen
#  Postal Codes:
#  ['97320']
# 106 . City : Albessen
#  Postal Codes:
#  ['66871']
# 107 . City : Albig
#  Postal Codes:
#  ['55234']
# 108 . City : Albisheim (Pfrimm)
#  Postal Codes:
#  ['67308']
# 109 . City : Albsfelde
#  Postal Codes:
#  ['23909']
# 110 . City : Albstadt
#  Postal Codes:
#  ['72458', '72459', '72461']
# 111 . City : Aldenhoven
#  Postal Codes:
#  ['52457']
# 112 . City : Aldersbach
#  Postal Codes:
#  ['94501']
# 113 . City : Aldingen
#  Postal Codes:
#  ['78554']
# 114 . City : Alerheim
#  Postal Codes:
#  ['86733']
# 115 . City : Alesheim
#  Postal Codes:
#  ['91793']
# 116 . City : Aletshausen
#  Postal Codes:
#  ['86480']
# 117 . City : Alf
#  Postal Codes:
#  ['56859']
# 118 . City : Alfdorf
#  Postal Codes:
#  ['73553', '73655']
# 119 . City : Alfeld
#  Postal Codes:
#  ['91236']
# 120 . City : Alfeld (Leine)
#  Postal Codes:
#  ['31061']
# 121 . City : Alfhausen
#  Postal Codes:
#  ['49594']
# 122 . City : Alflen
#  Postal Codes:
#  ['56828']
# 123 . City : Alfstedt
#  Postal Codes:
#  ['27432']
# 124 . City : Alfter
#  Postal Codes:
#  ['53347']
# 125 . City : Algermissen
#  Postal Codes:
#  ['31191']
# 126 . City : Alheim
#  Postal Codes:
#  ['36211']
# 127 . City : Alken
#  Postal Codes:
#  ['56332']
# 128 . City : Alkersleben
#  Postal Codes:
#  ['99310']
# 129 . City : Alkersum
#  Postal Codes:
#  ['25938']
# 130 . City : Allenbach
#  Postal Codes:
#  ['55758']
# 131 . City : Allendorf
#  Postal Codes:
#  ['35469', '35108', '56370', '7426']
# 132 . City : Allenfeld
#  Postal Codes:
#  ['55595']
# 133 . City : Allensbach
#  Postal Codes:
#  ['78476']
# 134 . City : Allersberg
#  Postal Codes:
#  ['90584']
# 135 . City : Allershausen
#  Postal Codes:
#  ['85391']
# 136 . City : Alleshausen
#  Postal Codes:
#  ['88422']
# 137 . City : Alling
#  Postal Codes:
#  ['82239']
# 138 . City : Allmannshofen
#  Postal Codes:
#  ['86695']
# 139 . City : Allmannsweiler
#  Postal Codes:
#  ['88348']
# 140 . City : Allmendingen
#  Postal Codes:
#  ['89604']
# 141 . City : Allmersbach im Tal
#  Postal Codes:
#  ['71573']
# 142 . City : Allstedt
#  Postal Codes:
#  ['6542']
# 143 . City : Almdorf
#  Postal Codes:
#  ['25821']
# 144 . City : Almersbach
#  Postal Codes:
#  ['57610']
# 145 . City : Alpen
#  Postal Codes:
#  ['46519']
# 146 . City : Alpenrod
#  Postal Codes:
#  ['57642', '57647']
# 147 . City : Alperstedt
#  Postal Codes:
#  ['99195']
# 148 . City : Alpirsbach
#  Postal Codes:
#  ['72275']
# 149 . City : Alsbach
#  Postal Codes:
#  ['56237']
# 150 . City : Alsbach-Hähnlein
#  Postal Codes:
#  ['64665']
# 151 . City : Alsdorf
#  Postal Codes:
#  ['52477', '57518', '54668']
# 152 . City : Alsenz
#  Postal Codes:
#  ['67821']
# 153 . City : Alsfeld
#  Postal Codes:
#  ['36304']
# 154 . City : Alsheim
#  Postal Codes:
#  ['67577']
# 155 . City : Alsleben
#  Postal Codes:
#  ['6425']
# 156 . City : Altbach
#  Postal Codes:
#  ['73776']
# 157 . City : Alt Bennebek
#  Postal Codes:
#  ['24848']
# 158 . City : Alt Bukow
#  Postal Codes:
#  ['18233']
# 159 . City : Altdöbern
#  Postal Codes:
#  ['3229']
# 160 . City : Altdorf
#  Postal Codes:
#  ['84032', '71155', '72655', '67482']
# 161 . City : Altdorf bei Nürnberg
#  Postal Codes:
#  ['90518']
# 162 . City : Alt Duvenstedt
#  Postal Codes:
#  ['24782', '24791', '24811']
# 163 . City : Altefähr
#  Postal Codes:
#  ['18573']
# 164 . City : Alteglofsheim
#  Postal Codes:
#  ['93087']
# 165 . City : Altena
#  Postal Codes:
#  ['58762']
# 166 . City : Altenahr
#  Postal Codes:
#  ['53505']
# 167 . City : Altenbamberg
#  Postal Codes:
#  ['55585']
# 168 . City : Altenbeken
#  Postal Codes:
#  ['33184']
# 169 . City : Altenberg
#  Postal Codes:
#  ['1773', '1778']
# 170 . City : Altenberga
#  Postal Codes:
#  ['7768']
# 171 . City : Altenberge
#  Postal Codes:
#  ['48341']
# 172 . City : Altenbeuthen
#  Postal Codes:
#  ['7338']
# 173 . City : Altenbuch
#  Postal Codes:
#  ['97901']
# 174 . City : Altenburg
#  Postal Codes:
#  ['4600']
# 175 . City : Altendiez
#  Postal Codes:
#  ['65624']
# 176 . City : Altendorf
#  Postal Codes:
#  ['92540', '96146']
# 177 . City : Altenfeld
#  Postal Codes:
#  ['98701']
# 178 . City : Altenglan
#  Postal Codes:
#  ['66885']
# 179 . City : Altengottern
#  Postal Codes:
#  ['99991']
# 180 . City : Altenhagen
#  Postal Codes:
#  ['17091']
# 181 . City : Altenhausen
#  Postal Codes:
#  ['39343']
# 182 . City : Altenhof
#  Postal Codes:
#  ['24340', '17209']
# 183 . City : Altenholz
#  Postal Codes:
#  ['24161']
# 184 . City : Altenkirchen
#  Postal Codes:
#  ['66903', '18556']
# 185 . City : Altenkirchen (Westerwald)
#  Postal Codes:
#  ['57610']
# 186 . City : Altenkrempe
#  Postal Codes:
#  ['23730']
# 187 . City : Altenkunstadt
#  Postal Codes:
#  ['96264']
# 188 . City : Altenmarkt a.d. Alz
#  Postal Codes:
#  ['83352']
# 189 . City : Altenmedingen
#  Postal Codes:
#  ['29575']
# 190 . City : Altenmoor
#  Postal Codes:
#  ['25335']
# 191 . City : Altenmünster
#  Postal Codes:
#  ['86450']
# 192 . City : Altenpleen
#  Postal Codes:
#  ['18445']
# 193 . City : Altenriet
#  Postal Codes:
#  ['72657']
# 194 . City : Altenstadt
#  Postal Codes:
#  ['63674', '86972', '89281']
# 195 . City : Altenstadt a.d.Waldnaab
#  Postal Codes:
#  ['92665']
# 196 . City : Altensteig
#  Postal Codes:
#  ['72213']
# 197 . City : Altenthann
#  Postal Codes:
#  ['93177']
# 198 . City : Altentreptow
#  Postal Codes:
#  ['17087']
# 199 . City : Alterkülz
#  Postal Codes:
#  ['56288']
# 200 . City : Altersbach
#  Postal Codes:
#  ['98587']
# 201 . City : Altertheim
#  Postal Codes:
#  ['97237']
# 202 . City : Altfraunhofen
#  Postal Codes:
#  ['84169']
# 203 . City : Althegnenberg
#  Postal Codes:
#  ['82278']
# 204 . City : Altheim
#  Postal Codes:
#  ['88499', '89605']
# 205 . City : Altheim (Alb)
#  Postal Codes:
#  ['89174']
# 206 . City : Althengstett
#  Postal Codes:
#  ['75382']
# 207 . City : Althornbach
#  Postal Codes:
#  ['66484']
# 208 . City : Althütte
#  Postal Codes:
#  ['71566']
# 209 . City : Althüttendorf
#  Postal Codes:
#  ['16247']
# 210 . City : Altkalen
#  Postal Codes:
#  ['17179']
# 211 . City : Altkirchen
#  Postal Codes:
#  ['4626']
# 212 . City : Alt Krenzlin
#  Postal Codes:
#  ['19288']
# 213 . City : Altlandsberg
#  Postal Codes:
#  ['15345']
# 214 . City : Altlay
#  Postal Codes:
#  ['56858']
# 215 . City : Altleiningen
#  Postal Codes:
#  ['67316', '67317']
# 216 . City : Altlußheim
#  Postal Codes:
#  ['68804']
# 217 . City : Altmannstein
#  Postal Codes:
#  ['93336']
# 218 . City : Altmärkische Höhe
#  Postal Codes:
#  ['39606', '39615']
# 219 . City : Altmärkische Wische
#  Postal Codes:
#  ['39615']
# 220 . City : Alt Meteln
#  Postal Codes:
#  ['19069']
# 221 . City : Altmittweida
#  Postal Codes:
#  ['9648']
# 222 . City : Alt Mölln
#  Postal Codes:
#  ['23881']
# 223 . City : Altomünster
#  Postal Codes:
#  ['85250']
# 224 . City : Altötting
#  Postal Codes:
#  ['84503']
# 225 . City : Altrich
#  Postal Codes:
#  ['54518']
# 226 . City : Altrip
#  Postal Codes:
#  ['67122']
# 227 . City : Altscheid
#  Postal Codes:
#  ['54636']
# 228 . City : Alt Schwerin
#  Postal Codes:
#  ['17214']
# 229 . City : Altshausen
#  Postal Codes:
#  ['88361']
# 230 . City : Altstrimmig
#  Postal Codes:
#  ['56858']
# 231 . City : Alt Sührkow
#  Postal Codes:
#  ['17166']
# 232 . City : Alt Tellin
#  Postal Codes:
#  ['17129']
# 233 . City : Alt Tucheband
#  Postal Codes:
#  ['15328']
# 234 . City : Altusried
#  Postal Codes:
#  ['87452']
# 235 . City : Altwarp
#  Postal Codes:
#  ['17375']
# 236 . City : Altweidelbach
#  Postal Codes:
#  ['55469']
# 237 . City : Altwigshagen
#  Postal Codes:
#  ['17379']
# 238 . City : Alt Zachun
#  Postal Codes:
#  ['19230']
# 239 . City : Alt Zauche-Wußwerk
#  Postal Codes:
#  ['15913']
# 240 . City : Alveslohe
#  Postal Codes:
#  ['25486']
# 241 . City : Alzenau
#  Postal Codes:
#  ['63755']
# 242 . City : Alzey
#  Postal Codes:
#  ['55232']
# 243 . City : Amberg
#  Postal Codes:
#  ['92224', '86854']
# 244 . City : Amelinghausen
#  Postal Codes:
#  ['21385']
# 245 . City : Amerang
#  Postal Codes:
#  ['83123']
# 246 . City : Amerdingen
#  Postal Codes:
#  ['86735']
# 247 . City : Am Großen Bruch
#  Postal Codes:
#  ['39393']
# 248 . City : Ammeldingen an der Our
#  Postal Codes:
#  ['54675']
# 249 . City : Ammeldingen bei Neuerburg
#  Postal Codes:
#  ['54673']
# 250 . City : Am Mellensee
#  Postal Codes:
#  ['15838']
# 251 . City : Ammerbuch
#  Postal Codes:
#  ['72119']
# 252 . City : Ammerndorf
#  Postal Codes:
#  ['90614']
# 253 . City : Ammersbek
#  Postal Codes:
#  ['22949']
# 254 . City : Ammerthal
#  Postal Codes:
#  ['92260']
# 255 . City : Am Ohmberg
#  Postal Codes:
#  ['37345']
# 256 . City : Amöneburg
#  Postal Codes:
#  ['35287']
# 257 . City : Amorbach
#  Postal Codes:
#  ['63916']
# 258 . City : Ampfing
#  Postal Codes:
#  ['84539']
# 259 . City : Am Salzhaff
#  Postal Codes:
#  ['18233']
# 260 . City : Amstetten
#  Postal Codes:
#  ['73340']
# 261 . City : Amt Neuhaus
#  Postal Codes:
#  ['19273']
# 262 . City : Amtsberg
#  Postal Codes:
#  ['9439']
# 263 . City : Amt Wachsenburg
#  Postal Codes:
#  ['99334']
# 264 . City : Amtzell
#  Postal Codes:
#  ['88279']
# 265 . City : Andechs
#  Postal Codes:
#  ['82346']
# 266 . City : Anderlingen
#  Postal Codes:
#  ['27446']
# 267 . City : Andernach
#  Postal Codes:
#  ['56626']
# 268 . City : An der Poststraße
#  Postal Codes:
#  ['6647']
# 269 . City : Andervenne
#  Postal Codes:
#  ['49832']
# 270 . City : Andisleben
#  Postal Codes:
#  ['99189']
# 271 . City : Angelbachtal
#  Postal Codes:
#  ['74918']
# 272 . City : Angelburg
#  Postal Codes:
#  ['35719']
# 273 . City : Angelroda
#  Postal Codes:
#  ['99338']
# 274 . City : Anger
#  Postal Codes:
#  ['83454']
# 275 . City : Angermünde
#  Postal Codes:
#  ['16278']
# 276 . City : Angern
#  Postal Codes:
#  ['39326', '39517']
# 277 . City : Anhausen
#  Postal Codes:
#  ['56584']
# 278 . City : Ankershagen
#  Postal Codes:
#  ['17219']
# 279 . City : Anklam
#  Postal Codes:
#  ['17389']
# 280 . City : Ankum
#  Postal Codes:
#  ['49577']
# 281 . City : Annaberg-Buchholz
#  Postal Codes:
#  ['9456']
# 282 . City : Annaburg
#  Postal Codes:
#  ['6925']
# 283 . City : Annweiler am Trifels
#  Postal Codes:
#  ['76855']
# 284 . City : Anröchte
#  Postal Codes:
#  ['59609']
# 285 . City : Anrode
#  Postal Codes:
#  ['99976']
# 286 . City : Ansbach
#  Postal Codes:
#  ['91522']
# 287 . City : Anschau
#  Postal Codes:
#  ['56729']
# 288 . City : Antdorf
#  Postal Codes:
#  ['82387']
# 289 . City : Antrifttal
#  Postal Codes:
#  ['36326']
# 290 . City : Antweiler
#  Postal Codes:
#  ['53533']
# 291 . City : Anzing
#  Postal Codes:
#  ['85646']
# 292 . City : Apelern
#  Postal Codes:
#  ['31552']
# 293 . City : Apen
#  Postal Codes:
#  ['26689']
# 294 . City : Apenburg-Winterfeld
#  Postal Codes:
#  ['38486']
# 295 . City : Apensen
#  Postal Codes:
#  ['21641']
# 296 . City : Apfeldorf
#  Postal Codes:
#  ['86974']
# 297 . City : Apfeltrach
#  Postal Codes:
#  ['87742']
# 298 . City : Apolda
#  Postal Codes:
#  ['99510']
# 299 . City : Appel
#  Postal Codes:
#  ['21279']
# 300 . City : Appen
#  Postal Codes:
#  ['25482']
# 301 . City : Appenheim
#  Postal Codes:
#  ['55437']
# 302 . City : Appenweier
#  Postal Codes:
#  ['77767']
# 303 . City : Arbach
#  Postal Codes:
#  ['56769']
# 304 . City : Arberg
#  Postal Codes:
#  ['91722']
# 305 . City : Aremberg
#  Postal Codes:
#  ['53533']
# 306 . City : Arendsee (Altmark)
#  Postal Codes:
#  ['39619']
# 307 . City : Arenrath
#  Postal Codes:
#  ['54518']
# 308 . City : Arenshausen
#  Postal Codes:
#  ['37318']
# 309 . City : Aresing
#  Postal Codes:
#  ['86561']
# 310 . City : Arft
#  Postal Codes:
#  ['56729']
# 311 . City : Argenbühl
#  Postal Codes:
#  ['88260']
# 312 . City : Argenschwang
#  Postal Codes:
#  ['55595']
# 313 . City : Argenthal
#  Postal Codes:
#  ['55496']
# 314 . City : Arholzen
#  Postal Codes:
#  ['37627']
# 315 . City : Arkebek
#  Postal Codes:
#  ['25767']
# 316 . City : Arlewatt
#  Postal Codes:
#  ['25860']
# 317 . City : Armsheim
#  Postal Codes:
#  ['55288']
# 318 . City : Armstedt
#  Postal Codes:
#  ['24616']
# 319 . City : Armstorf
#  Postal Codes:
#  ['21769']
# 320 . City : Arnbruck
#  Postal Codes:
#  ['93471']
# 321 . City : Arneburg
#  Postal Codes:
#  ['39596']
# 322 . City : Arnis
#  Postal Codes:
#  ['24399']
# 323 . City : Arnsberg
#  Postal Codes:
#  ['59755', '59757', '59759', '59821', '59823']
# 324 . City : Arnschwang
#  Postal Codes:
#  ['93473']
# 325 . City : Arnsdorf
#  Postal Codes:
#  ['1477']
# 326 . City : Arnshöfen
#  Postal Codes:
#  ['56244']
# 327 . City : Arnstadt
#  Postal Codes:
#  ['99310']
# 328 . City : Arnstein
#  Postal Codes:
#  ['97450', '6333', '6456', '6543']
# 329 . City : Arnstorf
#  Postal Codes:
#  ['94424']
# 330 . City : Arpsdorf
#  Postal Codes:
#  ['24634']
# 331 . City : Arrach
#  Postal Codes:
#  ['93474']
# 332 . City : Artern/Unstrut
#  Postal Codes:
#  ['6556']
# 333 . City : Artlenburg
#  Postal Codes:
#  ['21380']
# 334 . City : Arzbach
#  Postal Codes:
#  ['56337']
# 335 . City : Arzberg
#  Postal Codes:
#  ['4886', '95659']
# 336 . City : Arzfeld
#  Postal Codes:
#  ['54687']
# 337 . City : Asbach
#  Postal Codes:
#  ['53567', '55758']
# 338 . City : Asbach-Bäumenheim
#  Postal Codes:
#  ['86663']
# 339 . City : Asbach-Sickenberg
#  Postal Codes:
#  ['37318']
# 340 . City : Ascha
#  Postal Codes:
#  ['94347']
# 341 . City : Aschaffenburg
#  Postal Codes:
#  ['63739', '63741', '63743']
# 342 . City : Aschau am Inn
#  Postal Codes:
#  ['84544']
# 343 . City : Aschau im Chiemgau
#  Postal Codes:
#  ['83229']
# 344 . City : Aschbach
#  Postal Codes:
#  ['67753']
# 345 . City : Ascheberg
#  Postal Codes:
#  ['59387', '24326']
# 346 . City : Ascheffel
#  Postal Codes:
#  ['24358']
# 347 . City : Aschenhausen
#  Postal Codes:
#  ['98634']
# 348 . City : Aschersleben
#  Postal Codes:
#  ['6449']
# 349 . City : Aschheim
#  Postal Codes:
#  ['85609']
# 350 . City : Asendorf
#  Postal Codes:
#  ['21271', '27330']
# 351 . City : Aspach
#  Postal Codes:
#  ['71546']
# 352 . City : Asperg
#  Postal Codes:
#  ['71679']
# 353 . City : Aspisheim
#  Postal Codes:
#  ['55459']
# 354 . City : Assamstadt
#  Postal Codes:
#  ['97959']
# 355 . City : Asselfingen
#  Postal Codes:
#  ['89176']
# 356 . City : Aßlar
#  Postal Codes:
#  ['35614']
# 357 . City : Aßling
#  Postal Codes:
#  ['85617']
# 358 . City : Astert
#  Postal Codes:
#  ['57627']
# 359 . City : Attendorn
#  Postal Codes:
#  ['57439']
# 360 . City : Attenhausen
#  Postal Codes:
#  ['56370']
# 361 . City : Attenhofen
#  Postal Codes:
#  ['84091']
# 362 . City : Attenkirchen
#  Postal Codes:
#  ['85395']
# 363 . City : Attenweiler
#  Postal Codes:
#  ['88448']
# 364 . City : Atting
#  Postal Codes:
#  ['94348']
# 365 . City : Atzelgift
#  Postal Codes:
#  ['57629']
# 366 . City : Au
#  Postal Codes:
#  ['79280']
# 367 . City : Au am Rhein
#  Postal Codes:
#  ['76474']
# 368 . City : Aub
#  Postal Codes:
#  ['97239']
# 369 . City : Aubstadt
#  Postal Codes:
#  ['97633']
# 370 . City : Auderath
#  Postal Codes:
#  ['56766']
# 371 . City : Aue
#  Postal Codes:
#  ['8280']
# 372 . City : Auel
#  Postal Codes:
#  ['56357']
# 373 . City : Auen
#  Postal Codes:
#  ['55569']
# 374 . City : Auengrund
#  Postal Codes:
#  ['98673']
# 375 . City : Auenwald
#  Postal Codes:
#  ['71549']
# 376 . City : Auerbach
#  Postal Codes:
#  ['8209', '9392', '94530']
# 377 . City : Auerbach in der Oberpfalz
#  Postal Codes:
#  ['91275']
# 378 . City : Auetal
#  Postal Codes:
#  ['31749']
# 379 . City : Aufhausen
#  Postal Codes:
#  ['93089']
# 380 . City : Aufseß
#  Postal Codes:
#  ['91347']
# 381 . City : Auggen
#  Postal Codes:
#  ['79424']
# 382 . City : Augsburg
#  Postal Codes:
#  ['86150', '86152', '86153', '86154', '86156', '86157', '86159', '86161', '86163', '86165', '86167', '86169', '86179', '86199']
# 383 . City : Augustdorf
#  Postal Codes:
#  ['32832']
# 384 . City : Augustusburg
#  Postal Codes:
#  ['9573']
# 385 . City : Auhagen
#  Postal Codes:
#  ['31553']
# 386 . City : Auhausen
#  Postal Codes:
#  ['86736']
# 387 . City : Au in der Hallertau
#  Postal Codes:
#  ['84072']
# 388 . City : Aukrug
#  Postal Codes:
#  ['24613']
# 389 . City : Aulendorf
#  Postal Codes:
#  ['88326']
# 390 . City : Aull
#  Postal Codes:
#  ['65582']
# 391 . City : Auma-Weidatal
#  Postal Codes:
#  ['7955']
# 392 . City : Aumühle
#  Postal Codes:
#  ['21521']
# 393 . City : Aura a.d.Saale
#  Postal Codes:
#  ['97717']
# 394 . City : Aurach
#  Postal Codes:
#  ['91589']
# 395 . City : Aurachtal
#  Postal Codes:
#  ['91086']
# 396 . City : Aura im Sinngrund
#  Postal Codes:
#  ['97773']
# 397 . City : Aurich
#  Postal Codes:
#  ['26603', '26605', '26607']
# 398 . City : Ausacker
#  Postal Codes:
#  ['24975']
# 399 . City : Ausleben
#  Postal Codes:
#  ['39393']
# 400 . City : Außernzell
#  Postal Codes:
#  ['94532']
# 401 . City : Auufer
#  Postal Codes:
#  ['25548']
# 402 . City : Auw an der Kyll
#  Postal Codes:
#  ['54664']
# 403 . City : Auw bei Prüm
#  Postal Codes:
#  ['54597']
# 404 . City : Aventoft
#  Postal Codes:
#  ['25927']
# 405 . City : Averlak
#  Postal Codes:
#  ['25715']
# 406 . City : Axstedt
#  Postal Codes:
#  ['27729']
# 407 . City : Aying
#  Postal Codes:
#  ['85653']
# 408 . City : Ayl
#  Postal Codes:
#  ['54441']
# 409 . City : Aystetten
#  Postal Codes:
#  ['86482']
# 410 . City : Baabe
#  Postal Codes:
#  ['18586']
# 411 . City : Baar
#  Postal Codes:
#  ['86674', '56729']
# 412 . City : Baar-Ebenhausen
#  Postal Codes:
#  ['85107']
# 413 . City : Babenhausen
#  Postal Codes:
#  ['64832', '87727']
# 414 . City : Babensham
#  Postal Codes:
#  ['83547']
# 415 . City : Bach an der Donau
#  Postal Codes:
#  ['93090']
# 416 . City : Bacharach
#  Postal Codes:
#  ['55422']
# 417 . City : Bachenberg
#  Postal Codes:
#  ['57610']
# 418 . City : Bachfeld
#  Postal Codes:
#  ['96528']
# 419 . City : Bachhagel
#  Postal Codes:
#  ['89429']
# 420 . City : Bächingen a.d.Brenz
#  Postal Codes:
#  ['89431']
# 421 . City : Backnang
#  Postal Codes:
#  ['71522']
# 422 . City : Bad Abbach
#  Postal Codes:
#  ['93077']
# 423 . City : Bad Aibling
#  Postal Codes:
#  ['83043']
# 424 . City : Bad Alexandersbad
#  Postal Codes:
#  ['95680']
# 425 . City : Bad Arolsen
#  Postal Codes:
#  ['34454']
# 426 . City : Bad Bayersoien
#  Postal Codes:
#  ['82435']
# 427 . City : Bad Bellingen
#  Postal Codes:
#  ['79415']
# 428 . City : Bad Belzig
#  Postal Codes:
#  ['14806']
# 429 . City : Bad Bentheim
#  Postal Codes:
#  ['48455']
# 430 . City : Badbergen
#  Postal Codes:
#  ['49635']
# 431 . City : Bad Bergzabern
#  Postal Codes:
#  ['76887']
# 432 . City : Bad Berka
#  Postal Codes:
#  ['99438']
# 433 . City : Bad Berleburg
#  Postal Codes:
#  ['57319']
# 434 . City : Bad Berneck im Fichtelgebirge
#  Postal Codes:
#  ['95460']
# 435 . City : Bad Bertrich
#  Postal Codes:
#  ['56864']
# 436 . City : Bad Bevensen
#  Postal Codes:
#  ['29549']
# 437 . City : Bad Bibra
#  Postal Codes:
#  ['6647']
# 438 . City : Bad Birnbach
#  Postal Codes:
#  ['84364']
# 439 . City : Bad Blankenburg
#  Postal Codes:
#  ['7422']
# 440 . City : Bad Bocklet
#  Postal Codes:
#  ['97708']
# 441 . City : Bad Bodenteich
#  Postal Codes:
#  ['29389']
# 442 . City : Bad Boll
#  Postal Codes:
#  ['73087']
# 443 . City : Bad Brambach
#  Postal Codes:
#  ['8648']
# 444 . City : Bad Bramstedt
#  Postal Codes:
#  ['24576']
# 445 . City : Bad Breisig
#  Postal Codes:
#  ['53498']
# 446 . City : Bad Brückenau
#  Postal Codes:
#  ['97769']
# 447 . City : Bad Buchau
#  Postal Codes:
#  ['88422']
# 448 . City : Bad Camberg
#  Postal Codes:
#  ['65520']
# 449 . City : Bad Colberg-Heldburg
#  Postal Codes:
#  ['98663']
# 450 . City : Baddeckenstedt
#  Postal Codes:
#  ['38271']
# 451 . City : Bad Ditzenbach
#  Postal Codes:
#  ['73312', '73342', '73345']
# 452 . City : Bad Doberan
#  Postal Codes:
#  ['18209']
# 453 . City : Bad Driburg
#  Postal Codes:
#  ['33014']
# 454 . City : Bad Düben
#  Postal Codes:
#  ['4849']
# 455 . City : Bad Dürkheim
#  Postal Codes:
#  ['67098']
# 456 . City : Bad Dürrenberg
#  Postal Codes:
#  ['6231']
# 457 . City : Bad Dürrheim
#  Postal Codes:
#  ['78073']
# 458 . City : Bad Eilsen
#  Postal Codes:
#  ['31707']
# 459 . City : Bad Elster
#  Postal Codes:
#  ['8645']
# 460 . City : Badem
#  Postal Codes:
#  ['54657']
# 461 . City : Bad Ems
#  Postal Codes:
#  ['56130']
# 462 . City : Bad Emstal
#  Postal Codes:
#  ['34308']
# 463 . City : Baden-Baden
#  Postal Codes:
#  ['76530', '76532', '76534']
# 464 . City : Bad Endbach
#  Postal Codes:
#  ['35080']
# 465 . City : Badendorf
#  Postal Codes:
#  ['23619']
# 466 . City : Bad Endorf
#  Postal Codes:
#  ['83093']
# 467 . City : Badenhard
#  Postal Codes:
#  ['56291']
# 468 . City : Badenheim
#  Postal Codes:
#  ['55576']
# 469 . City : Badenweiler
#  Postal Codes:
#  ['79410']
# 470 . City : Bad Essen
#  Postal Codes:
#  ['49152']
# 471 . City : Bad Fallingbostel
#  Postal Codes:
#  ['29683']
# 472 . City : Bad Feilnbach
#  Postal Codes:
#  ['83075']
# 473 . City : Bad Frankenhausen/Kyffhäuser
#  Postal Codes:
#  ['6567']
# 474 . City : Bad Freienwalde (Oder)
#  Postal Codes:
#  ['16259']
# 475 . City : Bad Friedrichshall
#  Postal Codes:
#  ['74177']
# 476 . City : Bad Füssing
#  Postal Codes:
#  ['94072']
# 477 . City : Bad Gandersheim
#  Postal Codes:
#  ['37581']
# 478 . City : Bad Gottleuba-Berggießhübel
#  Postal Codes:
#  ['1816']
# 479 . City : Bad Griesbach i.Rottal
#  Postal Codes:
#  ['94086']
# 480 . City : Bad Grönenbach
#  Postal Codes:
#  ['87730']
# 481 . City : Bad Grund
#  Postal Codes:
#  ['37539']
# 482 . City : Bad Harzburg
#  Postal Codes:
#  ['38667']
# 483 . City : Bad Heilbrunn
#  Postal Codes:
#  ['83670']
# 484 . City : Bad Herrenalb
#  Postal Codes:
#  ['76332']
# 485 . City : Bad Hersfeld
#  Postal Codes:
#  ['36251']
# 486 . City : Bad Hindelang
#  Postal Codes:
#  ['87541']
# 487 . City : Bad Homburg v. d. Höhe
#  Postal Codes:
#  ['61348', '61350', '61352']
# 488 . City : Bad Honnef
#  Postal Codes:
#  ['53604']
# 489 . City : Bad Hönningen
#  Postal Codes:
#  ['53547', '53557']
# 490 . City : Bad Iburg
#  Postal Codes:
#  ['49186']
# 491 . City : Bad Karlshafen
#  Postal Codes:
#  ['34385']
# 492 . City : Bad Kissingen
#  Postal Codes:
#  ['97688']
# 493 . City : Bad Kleinen
#  Postal Codes:
#  ['23996']
# 494 . City : Bad Klosterlausnitz
#  Postal Codes:
#  ['7639']
# 495 . City : Bad Kohlgrub
#  Postal Codes:
#  ['82433']
# 496 . City : Bad König
#  Postal Codes:
#  ['64732']
# 497 . City : Bad Königshofen i.Grabfeld
#  Postal Codes:
#  ['97631']
# 498 . City : Bad Köstritz
#  Postal Codes:
#  ['7586']
# 499 . City : Bad Kötzting
#  Postal Codes:
#  ['93444']
# 500 . City : Bad Kreuznach
#  Postal Codes:
#  ['55543', '55545', '55583']
# 501 . City : Bad Krozingen
#  Postal Codes:
#  ['79189']
# 502 . City : Bad Laasphe
#  Postal Codes:
#  ['57334']
# 503 . City : Bad Laer
#  Postal Codes:
#  ['49196']
# 504 . City : Bad Langensalza
#  Postal Codes:
#  ['99947']
# 505 . City : Bad Lauchstädt
#  Postal Codes:
#  ['6246']
# 506 . City : Bad Lausick
#  Postal Codes:
#  ['4651']
# 507 . City : Bad Lauterberg
#  Postal Codes:
#  ['37431']
# 508 . City : Bad Liebenstein
#  Postal Codes:
#  ['36448']
# 509 . City : Bad Liebenwerda
#  Postal Codes:
#  ['4895', '4924', '4931']
# 510 . City : Bad Liebenzell
#  Postal Codes:
#  ['75378']
# 511 . City : Bad Lippspringe
#  Postal Codes:
#  ['33175']
# 512 . City : Bad Lobenstein
#  Postal Codes:
#  ['7356']
# 513 . City : Bad Marienberg (Westerwald)
#  Postal Codes:
#  ['56470']
# 514 . City : Bad Mergentheim
#  Postal Codes:
#  ['97980']
# 515 . City : Bad Münder am Deister
#  Postal Codes:
#  ['31848']
# 516 . City : Bad Münstereifel
#  Postal Codes:
#  ['53902']
# 517 . City : Bad Muskau
#  Postal Codes:
#  ['2953']
# 518 . City : Bad Nauheim
#  Postal Codes:
#  ['61231']
# 519 . City : Bad Nenndorf
#  Postal Codes:
#  ['31542']
# 520 . City : Bad Neuenahr-Ahrweiler
#  Postal Codes:
#  ['53474']
# 521 . City : Bad Neustadt an der Saale
#  Postal Codes:
#  ['97616']
# 522 . City : Bad Oeynhausen
#  Postal Codes:
#  ['32545', '32547', '32549']
# 523 . City : Bad Oldesloe
#  Postal Codes:
#  ['23843']
# 524 . City : Bad Orb
#  Postal Codes:
#  ['63619']
# 525 . City : Bad Peterstal-Griesbach
#  Postal Codes:
#  ['72250', '77740']
# 526 . City : Bad Pyrmont
#  Postal Codes:
#  ['31812']
# 527 . City : Bad Rappenau
#  Postal Codes:
#  ['74906']
# 528 . City : Bad Reichenhall
#  Postal Codes:
#  ['83435']
# 529 . City : Bad Rippoldsau-Schapbach
#  Postal Codes:
#  ['77776']
# 530 . City : Bad Rodach
#  Postal Codes:
#  ['96476']
# 531 . City : Bad Rothenfelde
#  Postal Codes:
#  ['49214']
# 532 . City : Bad Saarow
#  Postal Codes:
#  ['15526']
# 533 . City : Bad Sachsa
#  Postal Codes:
#  ['37441']
# 534 . City : Bad Säckingen
#  Postal Codes:
#  ['79713']
# 535 . City : Bad Salzdetfurth
#  Postal Codes:
#  ['31162']
# 536 . City : Bad Salzschlirf
#  Postal Codes:
#  ['36364']
# 537 . City : Bad Salzuflen
#  Postal Codes:
#  ['32105', '32107', '32108']
# 538 . City : Bad Salzungen
#  Postal Codes:
#  ['36433']
# 539 . City : Bad Sassendorf
#  Postal Codes:
#  ['59505']
# 540 . City : Bad Saulgau
#  Postal Codes:
#  ['88348']
# 541 . City : Bad Schandau
#  Postal Codes:
#  ['1814']
# 542 . City : Bad Schlema
#  Postal Codes:
#  ['8301']
# 543 . City : Bad Schmiedeberg
#  Postal Codes:
#  ['6905']
# 544 . City : Bad Schönborn
#  Postal Codes:
#  ['76669']
# 545 . City : Bad Schussenried
#  Postal Codes:
#  ['88427']
# 546 . City : Bad Schwalbach
#  Postal Codes:
#  ['65307']
# 547 . City : Bad Schwartau
#  Postal Codes:
#  ['23611']
# 548 . City : Bad Segeberg
#  Postal Codes:
#  ['23795']
# 549 . City : Bad Sobernheim
#  Postal Codes:
#  ['55566']
# 550 . City : Bad Soden
#  Postal Codes:
#  ['65812']
# 551 . City : Bad Soden-Salmünster
#  Postal Codes:
#  ['63628']
# 552 . City : Bad Sooden-Allendorf
#  Postal Codes:
#  ['37242']
# 553 . City : Bad Staffelstein
#  Postal Codes:
#  ['96231']
# 554 . City : Bad Steben
#  Postal Codes:
#  ['95138']
# 555 . City : Bad Sulza
#  Postal Codes:
#  ['99510', '99518']
# 556 . City : Bad Sülze
#  Postal Codes:
#  ['18334']
# 557 . City : Bad Teinach-Zavelstein
#  Postal Codes:
#  ['75385']
# 558 . City : Bad Tennstedt
#  Postal Codes:
#  ['99955']
# 559 . City : Bad Tölz
#  Postal Codes:
#  ['83646']
# 560 . City : Bad Überkingen
#  Postal Codes:
#  ['73337']
# 561 . City : Bad Urach
#  Postal Codes:
#  ['72574']
# 562 . City : Bad Vilbel
#  Postal Codes:
#  ['61118']
# 563 . City : Bad Waldsee
#  Postal Codes:
#  ['88339']
# 564 . City : Bad Wiessee
#  Postal Codes:
#  ['83707']
# 565 . City : Bad Wildbad
#  Postal Codes:
#  ['75323']
# 566 . City : Bad Wildungen
#  Postal Codes:
#  ['34537']
# 567 . City : Bad Wilsnack
#  Postal Codes:
#  ['19336']
# 568 . City : Bad Wimpfen
#  Postal Codes:
#  ['74206']
# 569 . City : Bad Windsheim
#  Postal Codes:
#  ['91438']
# 570 . City : Bad Wörishofen
#  Postal Codes:
#  ['86825']
# 571 . City : Bad Wünnenberg
#  Postal Codes:
#  ['33181']
# 572 . City : Bad Wurzach
#  Postal Codes:
#  ['88410']
# 573 . City : Bad Zwesten
#  Postal Codes:
#  ['34596']
# 574 . City : Bad Zwischenahn
#  Postal Codes:
#  ['26160']
# 575 . City : Baesweiler
#  Postal Codes:
#  ['52499']
# 576 . City : Bahlingen
#  Postal Codes:
#  ['79353']
# 577 . City : Bahrdorf
#  Postal Codes:
#  ['38459']
# 578 . City : Bahrenborstel
#  Postal Codes:
#  ['27245']
# 579 . City : Bahrenfleth
#  Postal Codes:
#  ['25569']
# 580 . City : Bahrenhof
#  Postal Codes:
#  ['23845']
# 581 . City : Bahretal
#  Postal Codes:
#  ['1819']
# 582 . City : Baienfurt
#  Postal Codes:
#  ['88255']
# 583 . City : Baierbach
#  Postal Codes:
#  ['84171']
# 584 . City : Baierbrunn
#  Postal Codes:
#  ['82065']
# 585 . City : Baiern
#  Postal Codes:
#  ['85625']
# 586 . City : Baiersbronn
#  Postal Codes:
#  ['72270']
# 587 . City : Baiersdorf
#  Postal Codes:
#  ['91083']
# 588 . City : Baindt
#  Postal Codes:
#  ['88255']
# 589 . City : Baisweil
#  Postal Codes:
#  ['87650']
# 590 . City : Bäk
#  Postal Codes:
#  ['23909']
# 591 . City : Bakum
#  Postal Codes:
#  ['49456']
# 592 . City : Bälau
#  Postal Codes:
#  ['23881']
# 593 . City : Balderschwang
#  Postal Codes:
#  ['87538']
# 594 . City : Baldringen
#  Postal Codes:
#  ['54314']
# 595 . City : Balduinstein
#  Postal Codes:
#  ['65558']
# 596 . City : Balesfeld
#  Postal Codes:
#  ['54597']
# 597 . City : Balge
#  Postal Codes:
#  ['31609']
# 598 . City : Balgheim
#  Postal Codes:
#  ['78582']
# 599 . City : Balgstädt
#  Postal Codes:
#  ['6632']
# 600 . City : Balingen
#  Postal Codes:
#  ['72336']
# 601 . City : Balje
#  Postal Codes:
#  ['21730']
# 602 . City : Ballendorf
#  Postal Codes:
#  ['89177']
# 603 . City : Ballenstedt
#  Postal Codes:
#  ['6493']
# 604 . City : Ballhausen
#  Postal Codes:
#  ['99955']
# 605 . City : Ballrechten-Dottingen
#  Postal Codes:
#  ['79282']
# 606 . City : Ballstädt
#  Postal Codes:
#  ['99869']
# 607 . City : Ballstedt
#  Postal Codes:
#  ['99439']
# 608 . City : Balow
#  Postal Codes:
#  ['19300']
# 609 . City : Baltmannsweiler
#  Postal Codes:
#  ['73666']
# 610 . City : Baltrum
#  Postal Codes:
#  ['26579']
# 611 . City : Balve
#  Postal Codes:
#  ['58802']
# 612 . City : Balzhausen
#  Postal Codes:
#  ['86483']
# 613 . City : Balzheim
#  Postal Codes:
#  ['88481']
# 614 . City : Bamberg
#  Postal Codes:
#  ['96047', '96049', '96050', '96052']
# 615 . City : Bammental
#  Postal Codes:
#  ['69245']
# 616 . City : Bandelin
#  Postal Codes:
#  ['17506']
# 617 . City : Bandenitz
#  Postal Codes:
#  ['19230']
# 618 . City : Bann
#  Postal Codes:
#  ['66851']
# 619 . City : Bannberscheid
#  Postal Codes:
#  ['56424']
# 620 . City : Bannewitz
#  Postal Codes:
#  ['1728']
# 621 . City : Banzkow
#  Postal Codes:
#  ['19079']
# 622 . City : Barbelroth
#  Postal Codes:
#  ['76889']
# 623 . City : Barbing
#  Postal Codes:
#  ['93092']
# 624 . City : Barby
#  Postal Codes:
#  ['39240', '39249']
# 625 . City : Barchfeld-Immelborn
#  Postal Codes:
#  ['36456']
# 626 . City : Bardowick
#  Postal Codes:
#  ['21357']
# 627 . City : Bärenbach
#  Postal Codes:
#  ['55483', '55758']
# 628 . City : Barenburg
#  Postal Codes:
#  ['27245']
# 629 . City : Barendorf
#  Postal Codes:
#  ['21397']
# 630 . City : Bärenstein
#  Postal Codes:
#  ['9471']
# 631 . City : Bärenthal
#  Postal Codes:
#  ['78580']
# 632 . City : Bargenstedt
#  Postal Codes:
#  ['25704']
# 633 . City : Bargfeld-Stegen
#  Postal Codes:
#  ['23863']
# 634 . City : Bargischow
#  Postal Codes:
#  ['17398']
# 635 . City : Bargstall
#  Postal Codes:
#  ['24806']
# 636 . City : Bargstedt
#  Postal Codes:
#  ['21698', '24793']
# 637 . City : Bargteheide
#  Postal Codes:
#  ['22941']
# 638 . City : Bargum
#  Postal Codes:
#  ['25842']
# 639 . City : Bark
#  Postal Codes:
#  ['23826']
# 640 . City : Barkelsby
#  Postal Codes:
#  ['24360']
# 641 . City : Barkenholm
#  Postal Codes:
#  ['25791']
# 642 . City : Barkhagen
#  Postal Codes:
#  ['19395']
# 643 . City : Barleben
#  Postal Codes:
#  ['39179']
# 644 . City : Barlt
#  Postal Codes:
#  ['25719']
# 645 . City : Barmissen
#  Postal Codes:
#  ['24245']
# 646 . City : Barmstedt
#  Postal Codes:
#  ['25355']
# 647 . City : Bärnau
#  Postal Codes:
#  ['95671']
# 648 . City : Barnekow
#  Postal Codes:
#  ['23968']
# 649 . City : Barnin
#  Postal Codes:
#  ['19089']
# 650 . City : Barnitz
#  Postal Codes:
#  ['23858']
# 651 . City : Barnstädt
#  Postal Codes:
#  ['6268']
# 652 . City : Barnstedt
#  Postal Codes:
#  ['21406']
# 653 . City : Barnstorf
#  Postal Codes:
#  ['49406']
# 654 . City : Barntrup
#  Postal Codes:
#  ['32683']
# 655 . City : Barsbek
#  Postal Codes:
#  ['24217']
# 656 . City : Barsbüttel
#  Postal Codes:
#  ['22885']
# 657 . City : Barsinghausen
#  Postal Codes:
#  ['30890']
# 658 . City : Barßel
#  Postal Codes:
#  ['26676']
# 659 . City : Bartenshagen-Parkentin
#  Postal Codes:
#  ['18209']
# 660 . City : Barth
#  Postal Codes:
#  ['18356']
# 661 . City : Bartholomä
#  Postal Codes:
#  ['73566']
# 662 . City : Bartow
#  Postal Codes:
#  ['17089']
# 663 . City : Barum
#  Postal Codes:
#  ['29576', '21357']
# 664 . City : Baruth/Mark
#  Postal Codes:
#  ['15837']
# 665 . City : Barver
#  Postal Codes:
#  ['49453']
# 666 . City : Barwedel
#  Postal Codes:
#  ['38476']
# 667 . City : Barweiler
#  Postal Codes:
#  ['53534']
# 668 . City : Bärweiler
#  Postal Codes:
#  ['55606']
# 669 . City : Basberg
#  Postal Codes:
#  ['54578']
# 670 . City : Basdahl
#  Postal Codes:
#  ['27432']
# 671 . City : Basedow
#  Postal Codes:
#  ['17139', '21483']
# 672 . City : Bassenheim
#  Postal Codes:
#  ['56220']
# 673 . City : Bassum
#  Postal Codes:
#  ['27211']
# 674 . City : Bastheim
#  Postal Codes:
#  ['97654']
# 675 . City : Basthorst
#  Postal Codes:
#  ['21493']
# 676 . City : Bastorf
#  Postal Codes:
#  ['18230']
# 677 . City : Battenberg
#  Postal Codes:
#  ['35088']
# 678 . City : Battenberg (Pfalz)
#  Postal Codes:
#  ['67271']
# 679 . City : Battweiler
#  Postal Codes:
#  ['66484']
# 680 . City : Baudenbach
#  Postal Codes:
#  ['91460']
# 681 . City : Bauler
#  Postal Codes:
#  ['53534', '54673']
# 682 . City : Baumgarten
#  Postal Codes:
#  ['18246', '18249']
# 683 . City : Baumholder
#  Postal Codes:
#  ['55774']
# 684 . City : Baunach
#  Postal Codes:
#  ['96148']
# 685 . City : Baunatal
#  Postal Codes:
#  ['34225']
# 686 . City : Bausendorf
#  Postal Codes:
#  ['54538']
# 687 . City : Baustert
#  Postal Codes:
#  ['54636']
# 688 . City : Bautzen
#  Postal Codes:
#  ['2625']
# 689 . City : Bawinkel
#  Postal Codes:
#  ['49844']
# 690 . City : Bayerbach
#  Postal Codes:
#  ['94137']
# 691 . City : Bayerbach b. Ergoldsbach
#  Postal Codes:
#  ['84092']
# 692 . City : Bayerfeld-Steckweiler
#  Postal Codes:
#  ['67808', '67822']
# 693 . City : Bayerisch Eisenstein
#  Postal Codes:
#  ['94252']
# 694 . City : Bayerisch Gmain
#  Postal Codes:
#  ['83457']
# 695 . City : Bayreuth
#  Postal Codes:
#  ['95444', '95445', '95447', '95448']
# 696 . City : Bayrischzell
#  Postal Codes:
#  ['83735']
# 697 . City : Bebensee
#  Postal Codes:
#  ['23816']
# 698 . City : Bebra
#  Postal Codes:
#  ['36179']
# 699 . City : Becheln
#  Postal Codes:
#  ['56132']
# 700 . City : Bechenheim
#  Postal Codes:
#  ['55234']
# 701 . City : Becherbach
#  Postal Codes:
#  ['67827']
# 702 . City : Becherbach bei Kirn
#  Postal Codes:
#  ['55608']
# 703 . City : Bechhofen
#  Postal Codes:
#  ['91572', '66894']
# 704 . City : Bechstedt
#  Postal Codes:
#  ['7426']
# 705 . City : Bechstedtstraß
#  Postal Codes:
#  ['99428']
# 706 . City : Bechtheim
#  Postal Codes:
#  ['67595']
# 707 . City : Bechtolsheim
#  Postal Codes:
#  ['55234']
# 708 . City : Bechtsrieth
#  Postal Codes:
#  ['92699']
# 709 . City : Beckdorf
#  Postal Codes:
#  ['21643']
# 710 . City : Beckedorf
#  Postal Codes:
#  ['31699']
# 711 . City : Beckeln
#  Postal Codes:
#  ['27243']
# 712 . City : Beckingen
#  Postal Codes:
#  ['66701']
# 713 . City : Beckum
#  Postal Codes:
#  ['59269']
# 714 . City : Bedburg
#  Postal Codes:
#  ['50181']
# 715 . City : Bedburg-Hau
#  Postal Codes:
#  ['47551']
# 716 . City : Bedesbach
#  Postal Codes:
#  ['66885']
# 717 . City : Beedenbostel
#  Postal Codes:
#  ['29355']
# 718 . City : Beelen
#  Postal Codes:
#  ['48361']
# 719 . City : Beelitz
#  Postal Codes:
#  ['14547']
# 720 . City : Beendorf
#  Postal Codes:
#  ['39343']
# 721 . City : Beerfelden
#  Postal Codes:
#  ['64743']
# 722 . City : Beeskow
#  Postal Codes:
#  ['15848']
# 723 . City : Beesten
#  Postal Codes:
#  ['49832']
# 724 . City : Beetzendorf
#  Postal Codes:
#  ['38489']
# 725 . City : Beetzsee
#  Postal Codes:
#  ['14778']
# 726 . City : Beetzseeheide
#  Postal Codes:
#  ['14778']
# 727 . City : Beggerow
#  Postal Codes:
#  ['17111']
# 728 . City : Behlendorf
#  Postal Codes:
#  ['23919']
# 729 . City : Behrendorf
#  Postal Codes:
#  ['25850']
# 730 . City : Behrenhoff
#  Postal Codes:
#  ['17498']
# 731 . City : Behren-Lübchin
#  Postal Codes:
#  ['17179']
# 732 . City : Behrensdorf
#  Postal Codes:
#  ['24321']
# 733 . City : Beichlingen
#  Postal Codes:
#  ['99625']
# 734 . City : Beidenfleth
#  Postal Codes:
#  ['25573']
# 735 . City : Beiersdorf
#  Postal Codes:
#  ['2736']
# 736 . City : Beiersdorf-Freudenberg
#  Postal Codes:
#  ['16259']
# 737 . City : Beierstedt
#  Postal Codes:
#  ['38382']
# 738 . City : Beilingen
#  Postal Codes:
#  ['54662']
# 739 . City : Beilngries
#  Postal Codes:
#  ['92339']
# 740 . City : Beilrode
#  Postal Codes:
#  ['4886']
# 741 . City : Beilstein
#  Postal Codes:
#  ['71543', '71717', '56814']
# 742 . City : Beimerstetten
#  Postal Codes:
#  ['89179']
# 743 . City : Beindersheim
#  Postal Codes:
#  ['67259']
# 744 . City : Beinerstadt
#  Postal Codes:
#  ['98660']
# 745 . City : Beinhausen
#  Postal Codes:
#  ['54552']
# 746 . City : Bekdorf
#  Postal Codes:
#  ['25554']
# 747 . City : Bekmünde
#  Postal Codes:
#  ['25524']
# 748 . City : Bekond
#  Postal Codes:
#  ['54340']
# 749 . City : Belau
#  Postal Codes:
#  ['24601']
# 750 . City : Beldorf
#  Postal Codes:
#  ['25557', '25767']
# 751 . City : Belg
#  Postal Codes:
#  ['56858']
# 752 . City : Belgern-Schildau
#  Postal Codes:
#  ['4874', '4889']
# 753 . City : Belgershain
#  Postal Codes:
#  ['4683']
# 754 . City : Belgweiler
#  Postal Codes:
#  ['55469']
# 755 . City : Bell
#  Postal Codes:
#  ['56745']
# 756 . City : Bellenberg
#  Postal Codes:
#  ['89287']
# 757 . City : Bellheim
#  Postal Codes:
#  ['76756']
# 758 . City : Bell (Hunsrück)
#  Postal Codes:
#  ['56288']
# 759 . City : Bellingen
#  Postal Codes:
#  ['56459']
# 760 . City : Bellstedt
#  Postal Codes:
#  ['99713']
# 761 . City : Belm
#  Postal Codes:
#  ['49191']
# 762 . City : Belrieth
#  Postal Codes:
#  ['98617']
# 763 . City : Belsch
#  Postal Codes:
#  ['19230']
# 764 . City : Beltheim
#  Postal Codes:
#  ['56290']
# 765 . City : Belum
#  Postal Codes:
#  ['21785']
# 766 . City : Bempflingen
#  Postal Codes:
#  ['72658']
# 767 . City : Bendestorf
#  Postal Codes:
#  ['21227']
# 768 . City : Bendfeld
#  Postal Codes:
#  ['24217']
# 769 . City : Bendorf
#  Postal Codes:
#  ['56170', '25557']
# 770 . City : Benediktbeuern
#  Postal Codes:
#  ['83671']
# 771 . City : Bengel
#  Postal Codes:
#  ['54538']
# 772 . City : Bengerstorf
#  Postal Codes:
#  ['19258']
# 773 . City : Benitz
#  Postal Codes:
#  ['18258']
# 774 . City : Benndorf
#  Postal Codes:
#  ['6308']
# 775 . City : Bennewitz
#  Postal Codes:
#  ['4828']
# 776 . City : Bennhausen
#  Postal Codes:
#  ['67808']
# 777 . City : Benningen
#  Postal Codes:
#  ['87734']
# 778 . City : Benningen am Neckar
#  Postal Codes:
#  ['71726']
# 779 . City : Bensdorf
#  Postal Codes:
#  ['14789']
# 780 . City : Benshausen
#  Postal Codes:
#  ['98554']
# 781 . City : Bensheim
#  Postal Codes:
#  ['64625']
# 782 . City : Bentwisch
#  Postal Codes:
#  ['18182']
# 783 . City : Bentzin
#  Postal Codes:
#  ['17129']
# 784 . City : Benz
#  Postal Codes:
#  ['17429', '23970']
# 785 . City : Benzweiler
#  Postal Codes:
#  ['55494']
# 786 . City : Beratzhausen
#  Postal Codes:
#  ['93176']
# 787 . City : Berching
#  Postal Codes:
#  ['92334']
# 788 . City : Berchtesgaden
#  Postal Codes:
#  ['83471']
# 789 . City : Bereborn
#  Postal Codes:
#  ['56769']
# 790 . City : Berenbach
#  Postal Codes:
#  ['56766']
# 791 . City : Berg
#  Postal Codes:
#  ['56357', '82335', '95180', '53505', '88276']
# 792 . City : Berga
#  Postal Codes:
#  ['6536']
# 793 . City : Berga/Elster
#  Postal Codes:
#  ['7980']
# 794 . City : Bergatreute
#  Postal Codes:
#  ['88368']
# 795 . City : Berg bei Neumarkt in der Oberpfalz
#  Postal Codes:
#  ['92348']
# 796 . City : Berge
#  Postal Codes:
#  ['19348', '49626']
# 797 . City : Bergen
#  Postal Codes:
#  ['8239', '83346', '91790', '55608', '29303']
# 798 . City : Bergen an der Dumme
#  Postal Codes:
#  ['29468']
# 799 . City : Bergen auf Rügen
#  Postal Codes:
#  ['18528']
# 800 . City : Bergenhausen
#  Postal Codes:
#  ['55469']
# 801 . City : Bergenhusen
#  Postal Codes:
#  ['24861']
# 802 . City : Bergewöhrden
#  Postal Codes:
#  ['25779']
# 803 . City : Bergfeld
#  Postal Codes:
#  ['38467']
# 804 . City : Berghaupten
#  Postal Codes:
#  ['77791']
# 805 . City : Berghausen
#  Postal Codes:
#  ['56368']
# 806 . City : Bergheim
#  Postal Codes:
#  ['50126', '50127', '50129', '86673']
# 807 . City : Bergholz
#  Postal Codes:
#  ['17321']
# 808 . City : Berghülen
#  Postal Codes:
#  ['89180']
# 809 . City : Berg im Gau
#  Postal Codes:
#  ['86562']
# 810 . City : Bergisch Gladbach
#  Postal Codes:
#  ['51427', '51429', '51465', '51467', '51469']
# 811 . City : Bergkamen
#  Postal Codes:
#  ['59192']
# 812 . City : Bergkirchen
#  Postal Codes:
#  ['85232']
# 813 . City : Berglangenbach
#  Postal Codes:
#  ['55776']
# 814 . City : Berglen
#  Postal Codes:
#  ['73663']
# 815 . City : Berglern
#  Postal Codes:
#  ['85459']
# 816 . City : Berglicht
#  Postal Codes:
#  ['54426']
# 817 . City : Bergneustadt
#  Postal Codes:
#  ['51702']
# 818 . City : Berg (Pfalz)
#  Postal Codes:
#  ['76768']
# 819 . City : Bergrheinfeld
#  Postal Codes:
#  ['97493']
# 820 . City : Bergtheim
#  Postal Codes:
#  ['97241']
# 821 . City : Bergweiler
#  Postal Codes:
#  ['54518']
# 822 . City : Beringstedt
#  Postal Codes:
#  ['25575']
# 823 . City : Berkatal
#  Postal Codes:
#  ['37297']
# 824 . City : Berka vor dem Hainich
#  Postal Codes:
#  ['99826']
# 825 . City : Berka/Werra
#  Postal Codes:
#  ['99837']
# 826 . City : Berkenbrück
#  Postal Codes:
#  ['15518']
# 827 . City : Berkenthin
#  Postal Codes:
#  ['23919']
# 828 . City : Berkheim
#  Postal Codes:
#  ['88450']
# 829 . City : Berkholz-Meyenburg
#  Postal Codes:
#  ['16306']
# 830 . City : Berkoth
#  Postal Codes:
#  ['54673']
# 831 . City : Berlin
#  Postal Codes:
#  ['10115', '10117', '10119', '10178', '10179', '10243', '10245', '10247', '10249', '10315', '10317', '10318', '10319', '10365', '10367', '10369', '10405', '10407', '10409', '10435', '10437', '10439', '10551', '10553', '10555', '10557', '10559', '10585', '10587', '10589', '10623', '10625', '10627', '10629', '10707', '10709', '10711', '10713', '10715', '10717', '10719', '10777', '10779', '10781', '10783', '10785', '10787', '10789', '10823', '10825', '10827', '10829', '10961', '10963', '10965', '10967', '10969', '10997', '10999', '12043', '12045', '12047', '12049', '12051', '12053', '12055', '12057', '12059', '12099', '12101', '12103', '12105', '12107', '12109', '12157', '12159', '12161', '12163', '12165', '12167', '12169', '12203', '12205', '12207', '12209', '12247', '12249', '12277', '12279', '12305', '12307', '12309', '12347', '12349', '12351', '12353', '12355', '12357', '12359', '12435', '12437', '12439', '12459', '12487', '12489', '12524', '12526', '12527', '12555', '12557', '12559', '12587', '12589', '12619', '12621', '12623', '12627', '12629', '12679', '12681', '12683', '12685', '12687', '12689', '13051', '13053', '13055', '13057', '13059', '13086', '13088', '13089', '13125', '13127', '13129', '13156', '13158', '13159', '13187', '13189', '13347', '13349', '13351', '13353', '13355', '13357', '13359', '13403', '13405', '13407', '13409', '13435', '13437', '13439', '13465', '13467', '13469', '13503', '13505', '13507', '13509', '13581', '13583', '13585', '13587', '13589', '13591', '13593', '13595', '13597', '13599', '13627', '13629', '14050', '14052', '14053', '14055', '14057', '14059', '14089', '14109', '14129', '14163', '14165', '14167', '14169', '14193', '14195', '14197', '14199']
# 832 . City : Berlingen
#  Postal Codes:
#  ['54570']
# 833 . City : Berlingerode
#  Postal Codes:
#  ['37339']
# 834 . City : Berlstedt
#  Postal Codes:
#  ['99439']
# 835 . City : Bermatingen
#  Postal Codes:
#  ['88697']
# 836 . City : Bermbach
#  Postal Codes:
#  ['98587']
# 837 . City : Bermel
#  Postal Codes:
#  ['56729']
# 838 . City : Bermersheim
#  Postal Codes:
#  ['67593']
# 839 . City : Bermersheim vor der Höhe
#  Postal Codes:
#  ['55234']
# 840 . City : Bernau
#  Postal Codes:
#  ['16321']
# 841 . City : Bernau am Chiemsee
#  Postal Codes:
#  ['83233']
# 842 . City : Bernau im Schwarzwald
#  Postal Codes:
#  ['79872']
# 843 . City : Bernbeuren
#  Postal Codes:
#  ['86975']
# 844 . City : Bernburg
#  Postal Codes:
#  ['6406']
# 845 . City : Berndorf
#  Postal Codes:
#  ['54578']
# 846 . City : Berndroth
#  Postal Codes:
#  ['56370']
# 847 . City : Berne
#  Postal Codes:
#  ['27804']
# 848 . City : Berngau
#  Postal Codes:
#  ['92361']
# 849 . City : Bernhardswald
#  Postal Codes:
#  ['93170']
# 850 . City : Bernitt
#  Postal Codes:
#  ['18246', '18249']
# 851 . City : Bernkastel-Kues
#  Postal Codes:
#  ['54470', '54492']
# 852 . City : Bernried
#  Postal Codes:
#  ['94505']
# 853 . City : Bernried am Starnberger See
#  Postal Codes:
#  ['82347']
# 854 . City : Bernsdorf
#  Postal Codes:
#  ['9337', '2994']
# 855 . City : Bernstadt
#  Postal Codes:
#  ['89182']
# 856 . City : Bernstadt auf dem Eigen
#  Postal Codes:
#  ['2748']
# 857 . City : Bernstorf
#  Postal Codes:
#  ['23936']
# 858 . City : Bernterode
#  Postal Codes:
#  ['37308']
# 859 . City : Berod bei Hachenburg
#  Postal Codes:
#  ['57614']
# 860 . City : Berod bei Wallmerod
#  Postal Codes:
#  ['56414']
# 861 . City : Berscheid
#  Postal Codes:
#  ['54673']
# 862 . City : Berschweiler bei Baumholder
#  Postal Codes:
#  ['55777']
# 863 . City : Berschweiler bei Kirn
#  Postal Codes:
#  ['55608']
# 864 . City : Bersenbrück
#  Postal Codes:
#  ['49593']
# 865 . City : Bersteland
#  Postal Codes:
#  ['15910']
# 866 . City : Bertsdorf-Hörnitz
# ...
# 10195 . City : Wirscheid
#  Postal Codes:
#  ['56237']
# 10196 . City : Wirschweiler
#  Postal Codes:
#  ['55758']
# 10197 . City : Wisch
#  Postal Codes:
#  ['24217', '25876']
# 10198 . City : Wischhafen
#  Postal Codes:
#  ['21737']
# 10199 . City : Wismar
#  Postal Codes:
#  ['23966', '23968', '23970']
# 10200 . City : Wissen
#  Postal Codes:
#  ['57537']
# 10201 . City : Wißmannsdorf
#  Postal Codes:
#  ['54636']
# 10202 . City : Wistedt
#  Postal Codes:
#  ['21255']
# 10203 . City : Witsum
#  Postal Codes:
#  ['25938']
# 10204 . City : Wittbek
#  Postal Codes:
#  ['25872']
# 10205 . City : Wittdün auf Amrum
#  Postal Codes:
#  ['25946']
# 10206 . City : Wittelshofen
#  Postal Codes:
#  ['91749']
# 10207 . City : Witten
#  Postal Codes:
#  ['58452', '58453', '58454', '58455', '58456']
# 10208 . City : Wittenbeck
#  Postal Codes:
#  ['18209']
# 10209 . City : Wittenberg
#  Postal Codes:
#  ['6886', '6888', '6889']
# 10210 . City : Wittenberge
#  Postal Codes:
#  ['19322']
# 10211 . City : Wittenbergen
#  Postal Codes:
#  ['25548']
# 10212 . City : Wittenborn
#  Postal Codes:
#  ['23829']
# 10213 . City : Wittenburg
#  Postal Codes:
#  ['19243']
# 10214 . City : Wittendörp
#  Postal Codes:
#  ['19243']
# 10215 . City : Wittenförden
#  Postal Codes:
#  ['19073']
# 10216 . City : Wittenhagen
#  Postal Codes:
#  ['18510']
# 10217 . City : Witterda
#  Postal Codes:
#  ['99189']
# 10218 . City : Wittgendorf
#  Postal Codes:
#  ['7318']
# 10219 . City : Wittgert
#  Postal Codes:
#  ['56237']
# 10220 . City : Wittibreut
#  Postal Codes:
#  ['84384']
# 10221 . City : Wittichenau
#  Postal Codes:
#  ['2997']
# 10222 . City : Wittighausen
#  Postal Codes:
#  ['97957']
# 10223 . City : Wittingen
#  Postal Codes:
#  ['29378', '29379']
# 10224 . City : Wittislingen
#  Postal Codes:
#  ['89426']
# 10225 . City : Wittlich
#  Postal Codes:
#  ['54516']
# 10226 . City : Wittlingen
#  Postal Codes:
#  ['79599']
# 10227 . City : Wittmar
#  Postal Codes:
#  ['38329']
# 10228 . City : Wittmoldt
#  Postal Codes:
#  ['24306']
# 10229 . City : Wittmund
#  Postal Codes:
#  ['26409']
# 10230 . City : Wittnau
#  Postal Codes:
#  ['79299']
# 10231 . City : Wittorf
#  Postal Codes:
#  ['21357']
# 10232 . City : Wittstock/Dosse
#  Postal Codes:
#  ['16909']
# 10233 . City : Witzeeze
#  Postal Codes:
#  ['21514']
# 10234 . City : Witzenhausen
#  Postal Codes:
#  ['37213', '37214', '37215', '37216', '37217', '37218']
# 10235 . City : Witzhave
#  Postal Codes:
#  ['22969']
# 10236 . City : Witzin
#  Postal Codes:
#  ['19406']
# 10237 . City : Witzleben
#  Postal Codes:
#  ['99310']
# 10238 . City : Witzmannsberg
#  Postal Codes:
#  ['94104']
# 10239 . City : Witzwort
#  Postal Codes:
#  ['25889']
# 10240 . City : Wöbbelin
#  Postal Codes:
#  ['19288']
# 10241 . City : Wobbenbüll
#  Postal Codes:
#  ['25856']
# 10242 . City : Woggersin
#  Postal Codes:
#  ['17039']
# 10243 . City : Wohlde
#  Postal Codes:
#  ['24899']
# 10244 . City : Wohlsborn
#  Postal Codes:
#  ['99439']
# 10245 . City : Wohltorf
#  Postal Codes:
#  ['21521']
# 10246 . City : Wohnste
#  Postal Codes:
#  ['27419']
# 10247 . City : Wohratal
#  Postal Codes:
#  ['35288']
# 10248 . City : Wöhrden
#  Postal Codes:
#  ['25797']
# 10249 . City : Wokuhl-Dabelow
#  Postal Codes:
#  ['17237']
# 10250 . City : Wolde
#  Postal Codes:
#  ['17091']
# 10251 . City : Woldegk
#  Postal Codes:
#  ['17348']
# 10252 . City : Woldert
#  Postal Codes:
#  ['57614']
# 10253 . City : Wolfach
#  Postal Codes:
#  ['77709']
# 10254 . City : Wolfegg
#  Postal Codes:
#  ['88364']
# 10255 . City : Wolfenbüttel
#  Postal Codes:
#  ['38300', '38302', '38304']
# 10256 . City : Wölferlingen
#  Postal Codes:
#  ['56244']
# 10257 . City : Wolferschwenda
#  Postal Codes:
#  ['99713']
# 10258 . City : Wolfersdorf
#  Postal Codes:
#  ['85395']
# 10259 . City : Wölfershausen
#  Postal Codes:
#  ['98617']
# 10260 . City : Wölfersheim
#  Postal Codes:
#  ['61200']
# 10261 . City : Wolferstadt
#  Postal Codes:
#  ['86709']
# 10262 . City : Wolfertschwenden
#  Postal Codes:
#  ['87787']
# 10263 . City : Wolfhagen
#  Postal Codes:
#  ['34466']
# 10264 . City : Wölfis
#  Postal Codes:
#  ['99885']
# 10265 . City : Wolframs-Eschenbach
#  Postal Codes:
#  ['91639']
# 10266 . City : Wolfratshausen
#  Postal Codes:
#  ['82515']
# 10267 . City : Wolfsberg
#  Postal Codes:
#  ['98704']
# 10268 . City : Wolfsburg
#  Postal Codes:
#  ['38440', '38442', '38444', '38446', '38448']
# 10269 . City : Wolfsburg-Unkeroda
#  Postal Codes:
#  ['99819']
# 10270 . City : Wolfschlugen
#  Postal Codes:
#  ['72649']
# 10271 . City : Wolfsegg
#  Postal Codes:
#  ['93195']
# 10272 . City : Wolfsheim
#  Postal Codes:
#  ['55578']
# 10273 . City : Wolfstein
#  Postal Codes:
#  ['67752']
# 10274 . City : Wolgast
#  Postal Codes:
#  ['17438']
# 10275 . City : Wolken
#  Postal Codes:
#  ['56332']
# 10276 . City : Wolkenstein
#  Postal Codes:
#  ['9429']
# 10277 . City : Wolkramshausen
#  Postal Codes:
#  ['99735']
# 10278 . City : Wollbach
#  Postal Codes:
#  ['97618']
# 10279 . City : Wollbrandshausen
#  Postal Codes:
#  ['37434']
# 10280 . City : Wollershausen
#  Postal Codes:
#  ['37434']
# 10281 . City : Wollin
#  Postal Codes:
#  ['14778']
# 10282 . City : Wollmerath
#  Postal Codes:
#  ['56826']
# 10283 . City : Wöllstadt
#  Postal Codes:
#  ['61206']
# 10284 . City : Wöllstein
#  Postal Codes:
#  ['55597']
# 10285 . City : Wolmersdorf
#  Postal Codes:
#  ['25704']
# 10286 . City : Wölmersen
#  Postal Codes:
#  ['57635']
# 10287 . City : Wolmirsleben
#  Postal Codes:
#  ['39435']
# 10288 . City : Wolmirstedt
#  Postal Codes:
#  ['39326']
# 10289 . City : Wolnzach
#  Postal Codes:
#  ['85283']
# 10290 . City : Wolpertshausen
#  Postal Codes:
#  ['74549']
# 10291 . City : Wolpertswende
#  Postal Codes:
#  ['88284']
# 10292 . City : Wölpinghausen
#  Postal Codes:
#  ['31556']
# 10293 . City : Wolsdorf
#  Postal Codes:
#  ['38379']
# 10294 . City : Wolsfeld
#  Postal Codes:
#  ['54636']
# 10295 . City : Woltersdorf
#  Postal Codes:
#  ['15569', '21516', '29497']
# 10296 . City : Womrath
#  Postal Codes:
#  ['55481']
# 10297 . City : Wonfurt
#  Postal Codes:
#  ['97539']
# 10298 . City : Wonneberg
#  Postal Codes:
#  ['83379']
# 10299 . City : Wonsees
#  Postal Codes:
#  ['96197']
# 10300 . City : Wonsheim
#  Postal Codes:
#  ['55599']
# 10301 . City : Woppenroth
#  Postal Codes:
#  ['55490']
# 10302 . City : Woringen
#  Postal Codes:
#  ['87789']
# 10303 . City : Worms
#  Postal Codes:
#  ['67547', '67549', '67550', '67551']
# 10304 . City : Wörnersberg
#  Postal Codes:
#  ['72299']
# 10305 . City : Wörnitz
#  Postal Codes:
#  ['91637']
# 10306 . City : Worpswede
#  Postal Codes:
#  ['27726']
# 10307 . City : Wörrstadt
#  Postal Codes:
#  ['55286']
# 10308 . City : Wört
#  Postal Codes:
#  ['73499']
# 10309 . City : Worth
#  Postal Codes:
#  ['21502']
# 10310 . City : Wörth
#  Postal Codes:
#  ['85457']
# 10311 . City : Wörth a.d. Isar
#  Postal Codes:
#  ['84109']
# 10312 . City : Wörth a.Main
#  Postal Codes:
#  ['63939']
# 10313 . City : Wörth am Rhein
#  Postal Codes:
#  ['76744']
# 10314 . City : Wörth an der Donau
#  Postal Codes:
#  ['93086']
# 10315 . City : Wörthsee
#  Postal Codes:
#  ['82237']
# 10316 . City : Wrangelsburg
#  Postal Codes:
#  ['17495']
# 10317 . City : Wredenhagen
#  Postal Codes:
#  ['17209']
# 10318 . City : Wrestedt
#  Postal Codes:
#  ['29559']
# 10319 . City : Wriedel
#  Postal Codes:
#  ['29565']
# 10320 . City : Wriezen
#  Postal Codes:
#  ['16269']
# 10321 . City : Wrist
#  Postal Codes:
#  ['25563']
# 10322 . City : Wrixum
#  Postal Codes:
#  ['25938']
# 10323 . City : Wrohm
#  Postal Codes:
#  ['25799']
# 10324 . City : Wülfershausen an der Saale
#  Postal Codes:
#  ['97618']
# 10325 . City : Wülfrath
#  Postal Codes:
#  ['42489']
# 10326 . City : Wulfsen
#  Postal Codes:
#  ['21445']
# 10327 . City : Wulfsmoor
#  Postal Codes:
#  ['25563']
# 10328 . City : Wulften am Harz
#  Postal Codes:
#  ['37199']
# 10329 . City : Wulkenzin
#  Postal Codes:
#  ['17039']
# 10330 . City : Wülknitz
#  Postal Codes:
#  ['1609']
# 10331 . City : Wundersleben
#  Postal Codes:
#  ['99610']
# 10332 . City : Wünschendorf/Elster
#  Postal Codes:
#  ['7570']
# 10333 . City : Wunsiedel
#  Postal Codes:
#  ['95632']
# 10334 . City : Wunstorf
#  Postal Codes:
#  ['31515']
# 10335 . City : Wuppertal
#  Postal Codes:
#  ['42103', '42105', '42107', '42109', '42111', '42113', '42115', '42117', '42119', '42275', '42277', '42279', '42281', '42283', '42285', '42287', '42289', '42327', '42329', '42349', '42369', '42389', '42399']
# 10336 . City : Wurmannsquick
#  Postal Codes:
#  ['84329']
# 10337 . City : Wurmberg
#  Postal Codes:
#  ['75449']
# 10338 . City : Wurmlingen
#  Postal Codes:
#  ['78573']
# 10339 . City : Wurmsham
#  Postal Codes:
#  ['84189']
# 10340 . City : Würrich
#  Postal Codes:
#  ['56858']
# 10341 . City : Würselen
#  Postal Codes:
#  ['52146']
# 10342 . City : Wurster Nordseeküste
#  Postal Codes:
#  ['27639']
# 10343 . City : Wurzbach
#  Postal Codes:
#  ['7343']
# 10344 . City : Würzburg
#  Postal Codes:
#  ['97070', '97072', '97074', '97076', '97078', '97080', '97082', '97084']
# 10345 . City : Wurzen
#  Postal Codes:
#  ['4808']
# 10346 . City : Würzweiler
#  Postal Codes:
#  ['67808']
# 10347 . City : Wüschheim
#  Postal Codes:
#  ['55471']
# 10348 . City : Wüstenrot
#  Postal Codes:
#  ['71543']
# 10349 . City : Wusterhausen/Dosse
#  Postal Codes:
#  ['16845', '16866', '16868']
# 10350 . City : Wusterhusen
#  Postal Codes:
#  ['17509']
# 10351 . City : Wustermark
#  Postal Codes:
#  ['14641']
# 10352 . City : Wusterwitz
#  Postal Codes:
#  ['14789']
# 10353 . City : Wust-Fischbeck
#  Postal Codes:
#  ['39524']
# 10354 . City : Wüstheuterode
#  Postal Codes:
#  ['37318']
# 10355 . City : Wustrow
#  Postal Codes:
#  ['18347', '17255', '29462']
# 10356 . City : Wutach
#  Postal Codes:
#  ['79879']
# 10357 . City : Wutha-Farnroda
#  Postal Codes:
#  ['99848']
# 10358 . City : Wutöschingen
#  Postal Codes:
#  ['79793']
# 10359 . City : Wyhl
#  Postal Codes:
#  ['79369']
# 10360 . City : Wyk auf Föhr
#  Postal Codes:
#  ['25938']
# 10361 . City : Xanten
#  Postal Codes:
#  ['46509']
# 10362 . City : Zaberfeld
#  Postal Codes:
#  ['74374']
# 10363 . City : Zachenberg
#  Postal Codes:
#  ['94239']
# 10364 . City : Zahna-Elster
#  Postal Codes:
#  ['6895']
# 10365 . City : Zaisenhausen
#  Postal Codes:
#  ['75059']
# 10366 . City : Zandt
#  Postal Codes:
#  ['93499']
# 10367 . City : Zangberg
#  Postal Codes:
#  ['84539']
# 10368 . City : Zapel
#  Postal Codes:
#  ['19089']
# 10369 . City : Zapfendorf
#  Postal Codes:
#  ['96199']
# 10370 . City : Zarnewanz
#  Postal Codes:
#  ['18195']
# 10371 . City : Zarpen
#  Postal Codes:
#  ['23619']
# 10372 . City : Zarrendorf
#  Postal Codes:
#  ['18510']
# 10373 . City : Zarrentin am Schaalsee
#  Postal Codes:
#  ['19246']
# 10374 . City : Zechin
#  Postal Codes:
#  ['15328']
# 10375 . City : Zedlitz
#  Postal Codes:
#  ['7557']
# 10376 . City : Zehdenick
#  Postal Codes:
#  ['16792']
# 10377 . City : Zehna
#  Postal Codes:
#  ['18276']
# 10378 . City : Zehnhausen bei Rennerod
#  Postal Codes:
#  ['56477']
# 10379 . City : Zehnhausen bei Wallmerod
#  Postal Codes:
#  ['56414']
# 10380 . City : Zehrental
#  Postal Codes:
#  ['39615']
# 10381 . City : Zeil am Main
#  Postal Codes:
#  ['97475']
# 10382 . City : Zeilarn
#  Postal Codes:
#  ['84367']
# 10383 . City : Zeiskam
#  Postal Codes:
#  ['67378']
# 10384 . City : Zeithain
#  Postal Codes:
#  ['1619']
# 10385 . City : Zeitlarn
#  Postal Codes:
#  ['93197']
# 10386 . City : Zeitlofs
#  Postal Codes:
#  ['97799']
# 10387 . City : Zeitz
#  Postal Codes:
#  ['6711', '6712']
# 10388 . City : Zell
#  Postal Codes:
#  ['93199']
# 10389 . City : Zell a. Main
#  Postal Codes:
#  ['97299']
# 10390 . City : Zella-Mehlis
#  Postal Codes:
#  ['98544']
# 10391 . City : Zell am Harmersbach
#  Postal Codes:
#  ['77736']
# 10392 . City : Zella/Rhön
#  Postal Codes:
#  ['36452']
# 10393 . City : Zellertal
#  Postal Codes:
#  ['67308']
# 10394 . City : Zell im Fichtelgebirge
#  Postal Codes:
#  ['95239']
# 10395 . City : Zell im Wiesental
#  Postal Codes:
#  ['79669']
# 10396 . City : Zellingen
#  Postal Codes:
#  ['97225']
# 10397 . City : Zell (Mosel)
#  Postal Codes:
#  ['56856', '56858', '56859']
# 10398 . City : Zell unter Aichelberg
#  Postal Codes:
#  ['73087', '73119']
# 10399 . City : Zeltingen-Rachtig
#  Postal Codes:
#  ['54492', '54539']
# 10400 . City : Zemitz
#  Postal Codes:
#  ['17440']
# 10401 . City : Zemmer
#  Postal Codes:
#  ['54313']
# 10402 . City : Zempin
#  Postal Codes:
#  ['17459']
# 10403 . City : Zendscheid
#  Postal Codes:
#  ['54655']
# 10404 . City : Zenting
#  Postal Codes:
#  ['94579']
# 10405 . City : Zepelin
#  Postal Codes:
#  ['18246']
# 10406 . City : Zepkow
#  Postal Codes:
#  ['17209']
# 10407 . City : Zerbst/Anhalt
#  Postal Codes:
#  ['39261', '39264']
# 10408 . City : Zerf
#  Postal Codes:
#  ['54314']
# 10409 . City : Zernien
#  Postal Codes:
#  ['29499']
# 10410 . City : Zernitz-Lohm
#  Postal Codes:
#  ['16845']
# 10411 . City : Zerrenthin
#  Postal Codes:
#  ['17309']
# 10412 . City : Zeschdorf
#  Postal Codes:
#  ['15326']
# 10413 . City : Zetel
#  Postal Codes:
#  ['26340']
# 10414 . City : Zettemin
#  Postal Codes:
#  ['17153']
# 10415 . City : Zettingen
#  Postal Codes:
#  ['56761']
# 10416 . City : Zettlitz
#  Postal Codes:
#  ['9306']
# 10417 . City : Zeulenroda-Triebes
#  Postal Codes:
#  ['7937', '7950']
# 10418 . City : Zeuthen
#  Postal Codes:
#  ['15738']
# 10419 . City : Zeven
#  Postal Codes:
#  ['27404']
# 10420 . City : Zichow
#  Postal Codes:
#  ['16306']
# 10421 . City : Zickhusen
#  Postal Codes:
#  ['19069']
# 10422 . City : Ziegelheim
#  Postal Codes:
#  ['4618']
# 10423 . City : Ziegendorf
#  Postal Codes:
#  ['19372']
# 10424 . City : Ziegenhain
#  Postal Codes:
#  ['57632']
# 10425 . City : Ziegenrück
#  Postal Codes:
#  ['7924']
# 10426 . City : Zielitz
#  Postal Codes:
#  ['39326']
# 10427 . City : Ziemetshausen
#  Postal Codes:
#  ['86473']
# 10428 . City : Zierenberg
#  Postal Codes:
#  ['34289']
# 10429 . City : Zierow
#  Postal Codes:
#  ['23968']
# 10430 . City : Ziertheim
#  Postal Codes:
#  ['89446']
# 10431 . City : Zierzow
#  Postal Codes:
#  ['19300']
# 10432 . City : Ziesar
#  Postal Codes:
#  ['14793']
# 10433 . City : Ziesendorf
#  Postal Codes:
#  ['18059']
# 10434 . City : Ziethen
#  Postal Codes:
#  ['16247', '17390', '23911']
# 10435 . City : Zilshausen
#  Postal Codes:
#  ['56288']
# 10436 . City : Ziltendorf
#  Postal Codes:
#  ['15295']
# 10437 . City : Zimmern
#  Postal Codes:
#  ['7778']
# 10438 . City : Zimmern ob Rottweil
#  Postal Codes:
#  ['78652', '78658']
# 10439 . City : Zimmernsupra
#  Postal Codes:
#  ['99100']
# 10440 . City : Zimmern unter der Burg
#  Postal Codes:
#  ['72369']
# 10441 . City : Zimmerschied
#  Postal Codes:
#  ['56379']
# 10442 . City : Zingst
#  Postal Codes:
#  ['18374']
# 10443 . City : Zinnowitz
#  Postal Codes:
#  ['17454']
# 10444 . City : Zirchow
#  Postal Codes:
#  ['17419']
# 10445 . City : Zirkow
#  Postal Codes:
#  ['18528']
# 10446 . City : Zirndorf
#  Postal Codes:
#  ['90513']
# 10447 . City : Zirzow
#  Postal Codes:
#  ['17039']
# 10448 . City : Zislow
#  Postal Codes:
#  ['17209']
# 10449 . City : Zittau
#  Postal Codes:
#  ['2763', '2788']
# 10450 . City : Zölkow
#  Postal Codes:
#  ['19374']
# 10451 . City : Zolling
#  Postal Codes:
#  ['85406']
# 10452 . City : Zöllnitz
#  Postal Codes:
#  ['7751']
# 10453 . City : Zörbig
#  Postal Codes:
#  ['6780']
# 10454 . City : Zorneding
#  Postal Codes:
#  ['85604']
# 10455 . City : Zornheim
#  Postal Codes:
#  ['55270']
# 10456 . City : Zöschingen
#  Postal Codes:
#  ['89447']
# 10457 . City : Zossen
#  Postal Codes:
#  ['15806']
# 10458 . City : Zotzenheim
#  Postal Codes:
#  ['55576']
# 10459 . City : Zschaitz-Ottewig
#  Postal Codes:
#  ['4720']
# 10460 . City : Zschepplin
#  Postal Codes:
#  ['4838']
# 10461 . City : Zschopau
#  Postal Codes:
#  ['9405', '9434']
# 10462 . City : Zschorlau
#  Postal Codes:
#  ['8321']
# 10463 . City : Zülow
#  Postal Codes:
#  ['19073']
# 10464 . City : Zülpich
#  Postal Codes:
#  ['53909']
# 10465 . City : Zurow
#  Postal Codes:
#  ['23992']
# 10466 . City : Zusamaltheim
#  Postal Codes:
#  ['86637']
# 10467 . City : Züsch
#  Postal Codes:
#  ['54422']
# 10468 . City : Zusmarshausen
#  Postal Codes:
#  ['86441']
# 10469 . City : Züsow
#  Postal Codes:
#  ['23992']
# 10470 . City : Züssow
#  Postal Codes:
#  ['17495']
# 10471 . City : Zuzenhausen
#  Postal Codes:
#  ['74939']
# 10472 . City : Zweibrücken
#  Postal Codes:
#  ['66482']
# 10473 . City : Zweifelscheid
#  Postal Codes:
#  ['54673']
# 10474 . City : Zweiflingen
#  Postal Codes:
#  ['74639']
# 10475 . City : Zwenkau
#  Postal Codes:
#  ['4442']
# 10476 . City : Zwickau
#  Postal Codes:
#  ['8056', '8058', '8060', '8062', '8064', '8066']
# 10477 . City : Zwiefalten
#  Postal Codes:
#  ['88529']
# 10478 . City : Zwiesel
#  Postal Codes:
#  ['94227']
# 10479 . City : Zwingenberg
#  Postal Codes:
#  ['69439', '64673']
# 10480 . City : Zwönitz
#  Postal Codes:
#  ['8297']

# %%
with open('code.txt') as f:
    data = f.read()
city_details = re.findall(r"\d+\s(?P<city>\D+)\s(?P<postal>\d+)", data)
output={}
for i,j in city_details:
    if i not in output.keys():
        output.update({i:[j]})
    if i in output.keys():
        output[i].append(j)
output
# Out:
# {'Aach': ['78267', '78267', '54298'],
#  'Aachen': ['52062',
#   '52062',
#   '52064',
#   '52066',
#   '52068',
#   '52070',
#   '52072',
#   '52074',
#   '52076',
#   '52078',
#   '52080'],
#  'Aalen': ['73430', '73430', '73431', '73432', '73433', '73434'],
#  'Aarbergen': ['65326', '65326'],
#  'Aasbüttel': ['25560', '25560'],
#  'Abenberg': ['91183', '91183'],
#  'Abensberg': ['93326', '93326'],
#  'Abentheuer': ['55767', '55767'],
#  'Absberg': ['91720', '91720'],
#  'Abstatt': ['74232', '74232'],
#  'Abtsbessingen': ['99713', '99713'],
#  'Abtsgmünd': ['73453', '73453'],
#  'Abtsteinach': ['69518', '69518'],
#  'Abtswind': ['97355', '97355'],
#  'Abtweiler': ['55568', '55568'],
#  'Achberg': ['88147', '88147'],
#  'Achern': ['77855', '77855'],
#  'Achim': ['28832', '28832'],
#  'Achslach': ['94250', '94250'],
#  'Achstetten': ['88480', '88480'],
#  'Acht': ['56729', '56729'],
#  'Achtelsbach': ['55767', '55767'],
#  'Achterwehr': ['24239', '24239'],
#  'Achtrup': ['25917', '25917'],
#  'Adelberg': ['73099', '73099'],
#  'Adelebsen': ['37139', '37139'],
#  'Adelheidsdorf': ['29352', '29352'],
#  'Adelmannsfelden': ['73486', '73486'],
#  'Adelschlag': ['85111', '85111'],
#  'Adelsdorf': ['91325', '91325'],
#  'Adelsheim': ['74740', '74740'],
#  'Adelshofen': ['91587', '91587', '82276'],
#  'Adelsried': ['86477', '86477'],
#  'Adelzhausen': ['86559', '86559'],
#  'Adenau': ['53518', '53518'],
#  'Adenbach': ['67742', '67742'],
#  'Adenbüttel': ['38528', '38528'],
#  'Adendorf': ['21365', '21365'],
#  'Adlkofen': ['84166', '84166'],
#  'Admannshagen-Bargeshagen': ['18211', '18211'],
#  'Adorf': ['8626', '8626'],
#  'Aebtissinwisch': ['25572', '25572'],
#  'Aerzen': ['31855', '31855'],
#  'Affalterbach': ['71563', '71563'],
#  'Affing': ['86444', '86444'],
#  'Affinghausen': ['27257', '27257'],
#  'Affler': ['54689', '54689'],
#  'Agathenburg': ['21684', '21684'],
#  'Agethorst': ['25560', '25560'],
#  'Aglasterhausen': ['74858', '74858'],
#  'Aham': ['84168', '84168'],
#  'Ahaus': ['48683', '48683'],
#  'Ahausen': ['27367', '27367'],
#  'Ahlbeck': ['17375', '17375'],
#  'Ahlden': ['29693', '29693'],
#  'Ahlefeld-Bistensee': ['24358', '24358'],
#  'Ahlen': ['59227', '59227', '59229'],
#  'Ahlerstedt': ['21702', '21702'],
#  'Ahlsdorf': ['6313', '6313'],
#  'Ahlstädt': ['98553', '98553'],
#  'Ahnatal': ['34292', '34292'],
#  'Ahneby': ['24996', '24996'],
#  'Ahnsbeck': ['29353', '29353'],
#  'Ahnsen': ['31708', '31708'],
#  'Aholfing': ['94345', '94345'],
#  'Aholming': ['94527', '94527'],
#  'Ahorn': ['74744', '74744', '96482'],
#  'Ahorntal': ['95491', '95491'],
#  'Ahrbrück': ['53506', '53506'],
#  'Ahrensbök': ['23623', '23623'],
#  'Ahrensburg': ['22926', '22926'],
#  'Ahrensfelde': ['16356', '16356'],
#  'Ahrenshagen-Daskow': ['18320', '18320'],
#  'Ahrenshöft': ['25853', '25853'],
#  'Ahrenshoop': ['18347', '18347'],
#  'Ahrenviöl': ['25885', '25885'],
#  'Ahrenviölfeld': ['24896', '24896', '25885'],
#  'Aichach': ['86551', '86551'],
#  'Aicha vorm Wald': ['94529', '94529'],
#  'Aichelberg': ['73101', '73101'],
#  'Aichen': ['86479', '86479'],
#  'Aichhalden': ['78733', '78733'],
#  'Aichstetten': ['88317', '88317'],
#  'Aichtal': ['72631', '72631'],
#  'Aichwald': ['73773', '73773'],
#  'Aidenbach': ['94501', '94501'],
#  'Aidhausen': ['97491', '97491'],
#  'Aidlingen': ['71134', '71134'],
#  'Aiglsbach': ['84089', '84089'],
#  'Ailertchen': ['56459', '56459'],
#  'Aindling': ['86447', '86447'],
#  'Ainring': ['83404', '83404'],
#  'Aislingen': ['89344', '89344'],
#  'Aiterhofen': ['94330', '94330'],
#  'Aitern': ['79677', '79677'],
#  'Aitrach': ['88319', '88319'],
#  'Aitrang': ['87648', '87648'],
#  'Aken (Elbe)': ['6385', '6385', '6386'],
#  'Aland': ['39615', '39615'],
#  'Albaching': ['83544', '83544'],
#  'Albbruck': ['79774', '79774'],
#  'Albersdorf': ['25767', '25767', '7646'],
#  'Albershausen': ['73095', '73095'],
#  'Albersweiler': ['76857', '76857'],
#  'Albertshofen': ['97320', '97320'],
#  'Albessen': ['66871', '66871'],
#  'Albig': ['55234', '55234'],
#  'Albisheim (Pfrimm)': ['67308', '67308'],
#  'Albsfelde': ['23909', '23909'],
#  'Albstadt': ['72458', '72458', '72459', '72461'],
#  'Aldenhoven': ['52457', '52457'],
#  'Aldersbach': ['94501', '94501'],
#  'Aldingen': ['78554', '78554'],
#  'Alerheim': ['86733', '86733'],
#  'Alesheim': ['91793', '91793'],
#  'Aletshausen': ['86480', '86480'],
#  'Alf': ['56859', '56859'],
#  'Alfdorf': ['73553', '73553', '73655'],
#  'Alfeld': ['91236', '91236'],
#  'Alfeld (Leine)': ['31061', '31061'],
#  'Alfhausen': ['49594', '49594'],
#  'Alflen': ['56828', '56828'],
#  'Alfstedt': ['27432', '27432'],
#  'Alfter': ['53347', '53347'],
#  'Algermissen': ['31191', '31191'],
#  'Alheim': ['36211', '36211'],
#  'Alken': ['56332', '56332'],
#  'Alkersleben': ['99310', '99310'],
#  'Alkersum': ['25938', '25938'],
#  'Allenbach': ['55758', '55758'],
#  'Allendorf': ['35469', '35469', '35108', '56370', '7426'],
#  'Allenfeld': ['55595', '55595'],
#  'Allensbach': ['78476', '78476'],
#  'Allersberg': ['90584', '90584'],
#  'Allershausen': ['85391', '85391'],
#  'Alleshausen': ['88422', '88422'],
#  'Alling': ['82239', '82239'],
#  'Allmannshofen': ['86695', '86695'],
#  'Allmannsweiler': ['88348', '88348'],
#  'Allmendingen': ['89604', '89604'],
#  'Allmersbach im Tal': ['71573', '71573'],
#  'Allstedt': ['6542', '6542'],
#  'Almdorf': ['25821', '25821'],
#  'Almersbach': ['57610', '57610'],
#  'Alpen': ['46519', '46519'],
#  'Alpenrod': ['57642', '57642', '57647'],
#  'Alperstedt': ['99195', '99195'],
#  'Alpirsbach': ['72275', '72275'],
#  'Alsbach': ['56237', '56237'],
#  'Alsbach-Hähnlein': ['64665', '64665'],
#  'Alsdorf': ['52477', '52477', '57518', '54668'],
#  'Alsenz': ['67821', '67821'],
#  'Alsfeld': ['36304', '36304'],
#  'Alsheim': ['67577', '67577'],
#  'Alsleben': ['6425', '6425'],
#  'Altbach': ['73776', '73776'],
#  'Alt Bennebek': ['24848', '24848'],
#  'Alt Bukow': ['18233', '18233'],
#  'Altdöbern': ['3229', '3229'],
#  'Altdorf': ['84032', '84032', '71155', '72655', '67482'],
#  'Altdorf bei Nürnberg': ['90518', '90518'],
#  'Alt Duvenstedt': ['24782', '24782', '24791', '24811'],
#  'Altefähr': ['18573', '18573'],
#  'Alteglofsheim': ['93087', '93087'],
#  'Altena': ['58762', '58762'],
#  'Altenahr': ['53505', '53505'],
#  'Altenbamberg': ['55585', '55585'],
#  'Altenbeken': ['33184', '33184'],
#  'Altenberg': ['1773', '1773', '1778'],
#  'Altenberga': ['7768', '7768'],
#  'Altenberge': ['48341', '48341'],
#  'Altenbeuthen': ['7338', '7338'],
#  'Altenbuch': ['97901', '97901'],
#  'Altenburg': ['4600', '4600'],
#  'Altendiez': ['65624', '65624'],
#  'Altendorf': ['92540', '92540', '96146'],
#  'Altenfeld': ['98701', '98701'],
#  'Altenglan': ['66885', '66885'],
#  'Altengottern': ['99991', '99991'],
#  'Altenhagen': ['17091', '17091'],
#  'Altenhausen': ['39343', '39343'],
#  'Altenhof': ['24340', '24340', '17209'],
#  'Altenholz': ['24161', '24161'],
#  'Altenkirchen': ['66903', '66903', '18556'],
#  'Altenkirchen (Westerwald)': ['57610', '57610'],
#  'Altenkrempe': ['23730', '23730'],
#  'Altenkunstadt': ['96264', '96264'],
#  'Altenmarkt a.d. Alz': ['83352', '83352'],
#  'Altenmedingen': ['29575', '29575'],
#  'Altenmoor': ['25335', '25335'],
#  'Altenmünster': ['86450', '86450'],
#  'Altenpleen': ['18445', '18445'],
#  'Altenriet': ['72657', '72657'],
#  'Altenstadt': ['63674', '63674', '86972', '89281'],
#  'Altenstadt a.d.Waldnaab': ['92665', '92665'],
#  'Altensteig': ['72213', '72213'],
#  'Altenthann': ['93177', '93177'],
#  'Altentreptow': ['17087', '17087'],
#  'Alterkülz': ['56288', '56288'],
#  'Altersbach': ['98587', '98587'],
#  'Altertheim': ['97237', '97237'],
#  'Altfraunhofen': ['84169', '84169'],
#  'Althegnenberg': ['82278', '82278'],
#  'Altheim': ['88499', '88499', '89605'],
#  'Altheim (Alb)': ['89174', '89174'],
#  'Althengstett': ['75382', '75382'],
#  'Althornbach': ['66484', '66484'],
#  'Althütte': ['71566', '71566'],
#  'Althüttendorf': ['16247', '16247'],
#  'Altkalen': ['17179', '17179'],
#  'Altkirchen': ['4626', '4626'],
#  'Alt Krenzlin': ['19288', '19288'],
#  'Altlandsberg': ['15345', '15345'],
#  'Altlay': ['56858', '56858'],
#  'Altleiningen': ['67316', '67316', '67317'],
#  'Altlußheim': ['68804', '68804'],
#  'Altmannstein': ['93336', '93336'],
#  'Altmärkische Höhe': ['39606', '39606', '39615'],
#  'Altmärkische Wische': ['39615', '39615'],
#  'Alt Meteln': ['19069', '19069'],
#  'Altmittweida': ['9648', '9648'],
#  'Alt Mölln': ['23881', '23881'],
#  'Altomünster': ['85250', '85250'],
#  'Altötting': ['84503', '84503'],
#  'Altrich': ['54518', '54518'],
#  'Altrip': ['67122', '67122'],
#  'Altscheid': ['54636', '54636'],
#  'Alt Schwerin': ['17214', '17214'],
#  'Altshausen': ['88361', '88361'],
#  'Altstrimmig': ['56858', '56858'],
#  'Alt Sührkow': ['17166', '17166'],
#  'Alt Tellin': ['17129', '17129'],
#  'Alt Tucheband': ['15328', '15328'],
#  'Altusried': ['87452', '87452'],
#  'Altwarp': ['17375', '17375'],
#  'Altweidelbach': ['55469', '55469'],
#  'Altwigshagen': ['17379', '17379'],
#  'Alt Zachun': ['19230', '19230'],
#  'Alt Zauche-Wußwerk': ['15913', '15913'],
#  'Alveslohe': ['25486', '25486'],
#  'Alzenau': ['63755', '63755'],
#  'Alzey': ['55232', '55232'],
#  'Amberg': ['92224', '92224', '86854'],
#  'Amelinghausen': ['21385', '21385'],
#  'Amerang': ['83123', '83123'],
#  'Amerdingen': ['86735', '86735'],
#  'Am Großen Bruch': ['39393', '39393'],
#  'Ammeldingen an der Our': ['54675', '54675'],
#  'Ammeldingen bei Neuerburg': ['54673', '54673'],
#  'Am Mellensee': ['15838', '15838'],
#  'Ammerbuch': ['72119', '72119'],
#  'Ammerndorf': ['90614', '90614'],
#  'Ammersbek': ['22949', '22949'],
#  'Ammerthal': ['92260', '92260'],
#  'Am Ohmberg': ['37345', '37345'],
#  'Amöneburg': ['35287', '35287'],
#  'Amorbach': ['63916', '63916'],
#  'Ampfing': ['84539', '84539'],
#  'Am Salzhaff': ['18233', '18233'],
#  'Amstetten': ['73340', '73340'],
#  'Amt Neuhaus': ['19273', '19273'],
#  'Amtsberg': ['9439', '9439'],
#  'Amt Wachsenburg': ['99334', '99334'],
#  'Amtzell': ['88279', '88279'],
#  'Andechs': ['82346', '82346'],
#  'Anderlingen': ['27446', '27446'],
#  'Andernach': ['56626', '56626'],
#  'An der Poststraße': ['6647', '6647'],
#  'Andervenne': ['49832', '49832'],
#  'Andisleben': ['99189', '99189'],
#  'Angelbachtal': ['74918', '74918'],
#  'Angelburg': ['35719', '35719'],
#  'Angelroda': ['99338', '99338'],
#  'Anger': ['83454', '83454'],
#  'Angermünde': ['16278', '16278'],
#  'Angern': ['39326', '39326', '39517'],
#  'Anhausen': ['56584', '56584'],
#  'Ankershagen': ['17219', '17219'],
#  'Anklam': ['17389', '17389'],
#  'Ankum': ['49577', '49577'],
#  'Annaberg-Buchholz': ['9456', '9456'],
#  'Annaburg': ['6925', '6925'],
#  'Annweiler am Trifels': ['76855', '76855'],
#  'Anröchte': ['59609', '59609'],
#  'Anrode': ['99976', '99976'],
#  'Ansbach': ['91522', '91522'],
#  'Anschau': ['56729', '56729'],
#  'Antdorf': ['82387', '82387'],
#  'Antrifttal': ['36326', '36326'],
#  'Antweiler': ['53533', '53533'],
#  'Anzing': ['85646', '85646'],
#  'Apelern': ['31552', '31552'],
#  'Apen': ['26689', '26689'],
#  'Apenburg-Winterfeld': ['38486', '38486'],
#  'Apensen': ['21641', '21641'],
#  'Apfeldorf': ['86974', '86974'],
#  'Apfeltrach': ['87742', '87742'],
#  'Apolda': ['99510', '99510'],
#  'Appel': ['21279', '21279'],
#  'Appen': ['25482', '25482'],
#  'Appenheim': ['55437', '55437'],
#  'Appenweier': ['77767', '77767'],
#  'Arbach': ['56769', '56769'],
#  'Arberg': ['91722', '91722'],
#  'Aremberg': ['53533', '53533'],
#  'Arendsee (Altmark)': ['39619', '39619'],
#  'Arenrath': ['54518', '54518'],
#  'Arenshausen': ['37318', '37318'],
#  'Aresing': ['86561', '86561'],
#  'Arft': ['56729', '56729'],
#  'Argenbühl': ['88260', '88260'],
#  'Argenschwang': ['55595', '55595'],
#  'Argenthal': ['55496', '55496'],
#  'Arholzen': ['37627', '37627'],
#  'Arkebek': ['25767', '25767'],
#  'Arlewatt': ['25860', '25860'],
#  'Armsheim': ['55288', '55288'],
#  'Armstedt': ['24616', '24616'],
#  'Armstorf': ['21769', '21769'],
#  'Arnbruck': ['93471', '93471'],
#  'Arneburg': ['39596', '39596'],
#  'Arnis': ['24399', '24399'],
#  'Arnsberg': ['59755', '59755', '59757', '59759', '59821', '59823'],
#  'Arnschwang': ['93473', '93473'],
#  'Arnsdorf': ['1477', '1477'],
#  'Arnshöfen': ['56244', '56244'],
#  'Arnstadt': ['99310', '99310'],
#  'Arnstein': ['97450', '97450', '6333', '6456', '6543'],
#  'Arnstorf': ['94424', '94424'],
#  'Arpsdorf': ['24634', '24634'],
#  'Arrach': ['93474', '93474'],
#  'Artern/Unstrut': ['6556', '6556'],
#  'Artlenburg': ['21380', '21380'],
#  'Arzbach': ['56337', '56337'],
#  'Arzberg': ['4886', '4886', '95659'],
#  'Arzfeld': ['54687', '54687'],
#  'Asbach': ['53567', '53567', '55758'],
#  'Asbach-Bäumenheim': ['86663', '86663'],
#  'Asbach-Sickenberg': ['37318', '37318'],
#  'Ascha': ['94347', '94347'],
#  'Aschaffenburg': ['63739', '63739', '63741', '63743'],
#  'Aschau am Inn': ['84544', '84544'],
#  'Aschau im Chiemgau': ['83229', '83229'],
#  'Aschbach': ['67753', '67753'],
#  'Ascheberg': ['59387', '59387', '24326'],
#  'Ascheffel': ['24358', '24358'],
#  'Aschenhausen': ['98634', '98634'],
#  'Aschersleben': ['6449', '6449'],
#  'Aschheim': ['85609', '85609'],
#  'Asendorf': ['21271', '21271', '27330'],
#  'Aspach': ['71546', '71546'],
#  'Asperg': ['71679', '71679'],
#  'Aspisheim': ['55459', '55459'],
#  'Assamstadt': ['97959', '97959'],
#  'Asselfingen': ['89176', '89176'],
#  'Aßlar': ['35614', '35614'],
#  'Aßling': ['85617', '85617'],
#  'Astert': ['57627', '57627'],
#  'Attendorn': ['57439', '57439'],
#  'Attenhausen': ['56370', '56370'],
#  'Attenhofen': ['84091', '84091'],
#  'Attenkirchen': ['85395', '85395'],
#  'Attenweiler': ['88448', '88448'],
#  'Atting': ['94348', '94348'],
#  'Atzelgift': ['57629', '57629'],
#  'Au': ['79280', '79280'],
#  'Au am Rhein': ['76474', '76474'],
#  'Aub': ['97239', '97239'],
#  'Aubstadt': ['97633', '97633'],
#  'Auderath': ['56766', '56766'],
#  'Aue': ['8280', '8280'],
#  'Auel': ['56357', '56357'],
#  'Auen': ['55569', '55569'],
#  'Auengrund': ['98673', '98673'],
#  'Auenwald': ['71549', '71549'],
#  'Auerbach': ['8209', '8209', '9392', '94530'],
#  'Auerbach in der Oberpfalz': ['91275', '91275'],
#  'Auetal': ['31749', '31749'],
#  'Aufhausen': ['93089', '93089'],
#  'Aufseß': ['91347', '91347'],
#  'Auggen': ['79424', '79424'],
#  'Augsburg': ['86150',
#   '86150',
#   '86152',
#   '86153',
#   '86154',
#   '86156',
#   '86157',
#   '86159',
#   '86161',
#   '86163',
#   '86165',
#   '86167',
#   '86169',
#   '86179',
#   '86199'],
#  'Augustdorf': ['32832', '32832'],
#  'Augustusburg': ['9573', '9573'],
#  'Auhagen': ['31553', '31553'],
#  'Auhausen': ['86736', '86736'],
#  'Au in der Hallertau': ['84072', '84072'],
#  'Aukrug': ['24613', '24613'],
#  'Aulendorf': ['88326', '88326'],
#  'Aull': ['65582', '65582'],
#  'Auma-Weidatal': ['7955', '7955'],
#  'Aumühle': ['21521', '21521'],
#  'Aura a.d.Saale': ['97717', '97717'],
#  'Aurach': ['91589', '91589'],
#  'Aurachtal': ['91086', '91086'],
#  'Aura im Sinngrund': ['97773', '97773'],
#  'Aurich': ['26603', '26603', '26605', '26607'],
#  'Ausacker': ['24975', '24975'],
#  'Ausleben': ['39393', '39393'],
#  'Außernzell': ['94532', '94532'],
#  'Auufer': ['25548', '25548'],
#  'Auw an der Kyll': ['54664', '54664'],
#  'Auw bei Prüm': ['54597', '54597'],
#  'Aventoft': ['25927', '25927'],
#  'Averlak': ['25715', '25715'],
#  'Axstedt': ['27729', '27729'],
#  'Aying': ['85653', '85653'],
#  'Ayl': ['54441', '54441'],
#  'Aystetten': ['86482', '86482'],
#  'Baabe': ['18586', '18586'],
#  'Baar': ['86674', '86674', '56729'],
#  'Baar-Ebenhausen': ['85107', '85107'],
#  'Babenhausen': ['64832', '64832', '87727'],
#  'Babensham': ['83547', '83547'],
#  'Bach an der Donau': ['93090', '93090'],
#  'Bacharach': ['55422', '55422'],
#  'Bachenberg': ['57610', '57610'],
#  'Bachfeld': ['96528', '96528'],
#  'Bachhagel': ['89429', '89429'],
#  'Bächingen a.d.Brenz': ['89431', '89431'],
#  'Backnang': ['71522', '71522'],
#  'Bad Abbach': ['93077', '93077'],
#  'Bad Aibling': ['83043', '83043'],
#  'Bad Alexandersbad': ['95680', '95680'],
#  'Bad Arolsen': ['34454', '34454'],
#  'Bad Bayersoien': ['82435', '82435'],
#  'Bad Bellingen': ['79415', '79415'],
#  'Bad Belzig': ['14806', '14806'],
#  'Bad Bentheim': ['48455', '48455'],
#  'Badbergen': ['49635', '49635'],
#  'Bad Bergzabern': ['76887', '76887'],
#  'Bad Berka': ['99438', '99438'],
#  'Bad Berleburg': ['57319', '57319'],
#  'Bad Berneck im Fichtelgebirge': ['95460', '95460'],
#  'Bad Bertrich': ['56864', '56864'],
#  'Bad Bevensen': ['29549', '29549'],
#  'Bad Bibra': ['6647', '6647'],
#  'Bad Birnbach': ['84364', '84364'],
#  'Bad Blankenburg': ['7422', '7422'],
#  'Bad Bocklet': ['97708', '97708'],
#  'Bad Bodenteich': ['29389', '29389'],
#  'Bad Boll': ['73087', '73087'],
#  'Bad Brambach': ['8648', '8648'],
#  'Bad Bramstedt': ['24576', '24576'],
#  'Bad Breisig': ['53498', '53498'],
#  'Bad Brückenau': ['97769', '97769'],
#  'Bad Buchau': ['88422', '88422'],
#  'Bad Camberg': ['65520', '65520'],
#  'Bad Colberg-Heldburg': ['98663', '98663'],
#  'Baddeckenstedt': ['38271', '38271'],
#  'Bad Ditzenbach': ['73312', '73312', '73342', '73345'],
#  'Bad Doberan': ['18209', '18209'],
#  'Bad Driburg': ['33014', '33014'],
#  'Bad Düben': ['4849', '4849'],
#  'Bad Dürkheim': ['67098', '67098'],
#  'Bad Dürrenberg': ['6231', '6231'],
#  'Bad Dürrheim': ['78073', '78073'],
#  'Bad Eilsen': ['31707', '31707'],
#  'Bad Elster': ['8645', '8645'],
#  'Badem': ['54657', '54657'],
#  'Bad Ems': ['56130', '56130'],
#  'Bad Emstal': ['34308', '34308'],
#  'Baden-Baden': ['76530', '76530', '76532', '76534'],
#  'Bad Endbach': ['35080', '35080'],
#  'Badendorf': ['23619', '23619'],
#  'Bad Endorf': ['83093', '83093'],
#  'Badenhard': ['56291', '56291'],
#  'Badenheim': ['55576', '55576'],
#  'Badenweiler': ['79410', '79410'],
#  'Bad Essen': ['49152', '49152'],
#  'Bad Fallingbostel': ['29683', '29683'],
#  'Bad Feilnbach': ['83075', '83075'],
#  'Bad Frankenhausen/Kyffhäuser': ['6567', '6567'],
#  'Bad Freienwalde (Oder)': ['16259', '16259'],
#  'Bad Friedrichshall': ['74177', '74177'],
#  'Bad Füssing': ['94072', '94072'],
#  'Bad Gandersheim': ['37581', '37581'],
#  'Bad Gottleuba-Berggießhübel': ['1816', '1816'],
#  'Bad Griesbach i.Rottal': ['94086', '94086'],
#  'Bad Grönenbach': ['87730', '87730'],
#  'Bad Grund': ['37539', '37539'],
#  'Bad Harzburg': ['38667', '38667'],
#  'Bad Heilbrunn': ['83670', '83670'],
#  'Bad Herrenalb': ['76332', '76332'],
#  'Bad Hersfeld': ['36251', '36251'],
#  'Bad Hindelang': ['87541', '87541'],
#  'Bad Homburg v. d. Höhe': ['61348', '61348', '61350', '61352'],
#  'Bad Honnef': ['53604', '53604'],
#  'Bad Hönningen': ['53547', '53547', '53557'],
#  'Bad Iburg': ['49186', '49186'],
#  'Bad Karlshafen': ['34385', '34385'],
#  'Bad Kissingen': ['97688', '97688'],
#  'Bad Kleinen': ['23996', '23996'],
#  'Bad Klosterlausnitz': ['7639', '7639'],
#  'Bad Kohlgrub': ['82433', '82433'],
#  'Bad König': ['64732', '64732'],
#  'Bad Königshofen i.Grabfeld': ['97631', '97631'],
#  'Bad Köstritz': ['7586', '7586'],
#  'Bad Kötzting': ['93444', '93444'],
#  'Bad Kreuznach': ['55543', '55543', '55545', '55583'],
#  'Bad Krozingen': ['79189', '79189'],
#  'Bad Laasphe': ['57334', '57334'],
#  'Bad Laer': ['49196', '49196'],
#  'Bad Langensalza': ['99947', '99947'],
#  'Bad Lauchstädt': ['6246', '6246'],
#  'Bad Lausick': ['4651', '4651'],
#  'Bad Lauterberg': ['37431', '37431'],
#  'Bad Liebenstein': ['36448', '36448'],
#  'Bad Liebenwerda': ['4895', '4895', '4924', '4931'],
#  'Bad Liebenzell': ['75378', '75378'],
#  'Bad Lippspringe': ['33175', '33175'],
#  'Bad Lobenstein': ['7356', '7356'],
#  'Bad Marienberg (Westerwald)': ['56470', '56470'],
#  'Bad Mergentheim': ['97980', '97980'],
#  'Bad Münder am Deister': ['31848', '31848'],
#  'Bad Münstereifel': ['53902', '53902'],
#  'Bad Muskau': ['2953', '2953'],
#  'Bad Nauheim': ['61231', '61231'],
#  'Bad Nenndorf': ['31542', '31542'],
#  'Bad Neuenahr-Ahrweiler': ['53474', '53474'],
#  'Bad Neustadt an der Saale': ['97616', '97616'],
#  'Bad Oeynhausen': ['32545', '32545', '32547', '32549'],
#  'Bad Oldesloe': ['23843', '23843'],
#  'Bad Orb': ['63619', '63619'],
#  'Bad Peterstal-Griesbach': ['72250', '72250', '77740'],
#  'Bad Pyrmont': ['31812', '31812'],
#  'Bad Rappenau': ['74906', '74906'],
#  'Bad Reichenhall': ['83435', '83435'],
#  'Bad Rippoldsau-Schapbach': ['77776', '77776'],
#  'Bad Rodach': ['96476', '96476'],
#  'Bad Rothenfelde': ['49214', '49214'],
#  'Bad Saarow': ['15526', '15526'],
#  'Bad Sachsa': ['37441', '37441'],
#  'Bad Säckingen': ['79713', '79713'],
#  'Bad Salzdetfurth': ['31162', '31162'],
#  'Bad Salzschlirf': ['36364', '36364'],
#  'Bad Salzuflen': ['32105', '32105', '32107', '32108'],
#  'Bad Salzungen': ['36433', '36433'],
#  'Bad Sassendorf': ['59505', '59505'],
#  'Bad Saulgau': ['88348', '88348'],
#  'Bad Schandau': ['1814', '1814'],
#  'Bad Schlema': ['8301', '8301'],
#  'Bad Schmiedeberg': ['6905', '6905'],
#  'Bad Schönborn': ['76669', '76669'],
#  'Bad Schussenried': ['88427', '88427'],
#  'Bad Schwalbach': ['65307', '65307'],
#  'Bad Schwartau': ['23611', '23611'],
#  'Bad Segeberg': ['23795', '23795'],
#  'Bad Sobernheim': ['55566', '55566'],
#  'Bad Soden': ['65812', '65812'],
#  'Bad Soden-Salmünster': ['63628', '63628'],
#  'Bad Sooden-Allendorf': ['37242', '37242'],
#  'Bad Staffelstein': ['96231', '96231'],
#  'Bad Steben': ['95138', '95138'],
#  'Bad Sulza': ['99510', '99510', '99518'],
#  'Bad Sülze': ['18334', '18334'],
#  'Bad Teinach-Zavelstein': ['75385', '75385'],
#  'Bad Tennstedt': ['99955', '99955'],
#  'Bad Tölz': ['83646', '83646'],
#  'Bad Überkingen': ['73337', '73337'],
#  'Bad Urach': ['72574', '72574'],
#  'Bad Vilbel': ['61118', '61118'],
#  'Bad Waldsee': ['88339', '88339'],
#  'Bad Wiessee': ['83707', '83707'],
#  'Bad Wildbad': ['75323', '75323'],
#  'Bad Wildungen': ['34537', '34537'],
#  'Bad Wilsnack': ['19336', '19336'],
#  'Bad Wimpfen': ['74206', '74206'],
#  'Bad Windsheim': ['91438', '91438'],
#  'Bad Wörishofen': ['86825', '86825'],
#  'Bad Wünnenberg': ['33181', '33181'],
#  'Bad Wurzach': ['88410', '88410'],
#  'Bad Zwesten': ['34596', '34596'],
#  'Bad Zwischenahn': ['26160', '26160'],
#  'Baesweiler': ['52499', '52499'],
#  'Bahlingen': ['79353', '79353'],
#  'Bahrdorf': ['38459', '38459'],
#  'Bahrenborstel': ['27245', '27245'],
#  'Bahrenfleth': ['25569', '25569'],
#  'Bahrenhof': ['23845', '23845'],
#  'Bahretal': ['1819', '1819'],
#  'Baienfurt': ['88255', '88255'],
#  'Baierbach': ['84171', '84171'],
#  'Baierbrunn': ['82065', '82065'],
#  'Baiern': ['85625', '85625'],
#  'Baiersbronn': ['72270', '72270'],
#  'Baiersdorf': ['91083', '91083'],
#  'Baindt': ['88255', '88255'],
#  'Baisweil': ['87650', '87650'],
#  'Bäk': ['23909', '23909'],
#  'Bakum': ['49456', '49456'],
#  'Bälau': ['23881', '23881'],
#  'Balderschwang': ['87538', '87538'],
#  'Baldringen': ['54314', '54314'],
#  'Balduinstein': ['65558', '65558'],
#  'Balesfeld': ['54597', '54597'],
#  'Balge': ['31609', '31609'],
#  'Balgheim': ['78582', '78582'],
#  'Balgstädt': ['6632', '6632'],
#  'Balingen': ['72336', '72336'],
#  'Balje': ['21730', '21730'],
#  'Ballendorf': ['89177', '89177'],
#  'Ballenstedt': ['6493', '6493'],
#  'Ballhausen': ['99955', '99955'],
#  'Ballrechten-Dottingen': ['79282', '79282'],
#  'Ballstädt': ['99869', '99869'],
#  'Ballstedt': ['99439', '99439'],
#  'Balow': ['19300', '19300'],
#  'Baltmannsweiler': ['73666', '73666'],
#  'Baltrum': ['26579', '26579'],
#  'Balve': ['58802', '58802'],
#  'Balzhausen': ['86483', '86483'],
#  'Balzheim': ['88481', '88481'],
#  'Bamberg': ['96047', '96047', '96049', '96050', '96052'],
#  'Bammental': ['69245', '69245'],
#  'Bandelin': ['17506', '17506'],
#  'Bandenitz': ['19230', '19230'],
#  'Bann': ['66851', '66851'],
#  'Bannberscheid': ['56424', '56424'],
#  'Bannewitz': ['1728', '1728'],
#  'Banzkow': ['19079', '19079'],
#  'Barbelroth': ['76889', '76889'],
#  'Barbing': ['93092', '93092'],
#  'Barby': ['39240', '39240', '39249'],
#  'Barchfeld-Immelborn': ['36456', '36456'],
#  'Bardowick': ['21357', '21357'],
#  'Bärenbach': ['55483', '55483', '55758'],
#  'Barenburg': ['27245', '27245'],
#  'Barendorf': ['21397', '21397'],
#  'Bärenstein': ['9471', '9471'],
#  'Bärenthal': ['78580', '78580'],
#  'Bargenstedt': ['25704', '25704'],
#  'Bargfeld-Stegen': ['23863', '23863'],
#  'Bargischow': ['17398', '17398'],
#  'Bargstall': ['24806', '24806'],
#  'Bargstedt': ['21698', '21698', '24793'],
#  'Bargteheide': ['22941', '22941'],
#  'Bargum': ['25842', '25842'],
#  'Bark': ['23826', '23826'],
#  'Barkelsby': ['24360', '24360'],
#  'Barkenholm': ['25791', '25791'],
#  'Barkhagen': ['19395', '19395'],
#  'Barleben': ['39179', '39179'],
#  'Barlt': ['25719', '25719'],
#  'Barmissen': ['24245', '24245'],
#  'Barmstedt': ['25355', '25355'],
#  'Bärnau': ['95671', '95671'],
#  'Barnekow': ['23968', '23968'],
#  'Barnin': ['19089', '19089'],
#  'Barnitz': ['23858', '23858'],
#  'Barnstädt': ['6268', '6268'],
#  'Barnstedt': ['21406', '21406'],
#  'Barnstorf': ['49406', '49406'],
#  'Barntrup': ['32683', '32683'],
#  'Barsbek': ['24217', '24217'],
#  'Barsbüttel': ['22885', '22885'],
#  'Barsinghausen': ['30890', '30890'],
#  'Barßel': ['26676', '26676'],
#  'Bartenshagen-Parkentin': ['18209', '18209'],
#  'Barth': ['18356', '18356'],
#  'Bartholomä': ['73566', '73566'],
#  'Bartow': ['17089', '17089'],
#  'Barum': ['29576', '29576', '21357'],
#  'Baruth/Mark': ['15837', '15837'],
#  'Barver': ['49453', '49453'],
#  'Barwedel': ['38476', '38476'],
#  'Barweiler': ['53534', '53534'],
#  'Bärweiler': ['55606', '55606'],
#  'Basberg': ['54578', '54578'],
#  'Basdahl': ['27432', '27432'],
#  'Basedow': ['17139', '17139', '21483'],
#  'Bassenheim': ['56220', '56220'],
#  'Bassum': ['27211', '27211'],
#  'Bastheim': ['97654', '97654'],
#  'Basthorst': ['21493', '21493'],
#  'Bastorf': ['18230', '18230'],
#  'Battenberg': ['35088', '35088'],
#  'Battenberg (Pfalz)': ['67271', '67271'],
#  'Battweiler': ['66484', '66484'],
#  'Baudenbach': ['91460', '91460'],
#  'Bauler': ['53534', '53534', '54673'],
#  'Baumgarten': ['18246', '18246', '18249'],
#  'Baumholder': ['55774', '55774'],
#  'Baunach': ['96148', '96148'],
#  'Baunatal': ['34225', '34225'],
#  'Bausendorf': ['54538', '54538'],
#  'Baustert': ['54636', '54636'],
#  'Bautzen': ['2625', '2625'],
#  'Bawinkel': ['49844', '49844'],
#  'Bayerbach': ['94137', '94137'],
#  'Bayerbach b. Ergoldsbach': ['84092', '84092'],
#  'Bayerfeld-Steckweiler': ['67808', '67808', '67822'],
#  'Bayerisch Eisenstein': ['94252', '94252'],
#  'Bayerisch Gmain': ['83457', '83457'],
#  'Bayreuth': ['95444', '95444', '95445', '95447', '95448'],
#  'Bayrischzell': ['83735', '83735'],
#  'Bebensee': ['23816', '23816'],
#  'Bebra': ['36179', '36179'],
#  'Becheln': ['56132', '56132'],
#  'Bechenheim': ['55234', '55234'],
#  'Becherbach': ['67827', '67827'],
#  'Becherbach bei Kirn': ['55608', '55608'],
#  'Bechhofen': ['91572', '91572', '66894'],
#  'Bechstedt': ['7426', '7426'],
#  'Bechstedtstraß': ['99428', '99428'],
#  'Bechtheim': ['67595', '67595'],
#  'Bechtolsheim': ['55234', '55234'],
#  'Bechtsrieth': ['92699', '92699'],
#  'Beckdorf': ['21643', '21643'],
#  'Beckedorf': ['31699', '31699'],
#  'Beckeln': ['27243', '27243'],
#  'Beckingen': ['66701', '66701'],
#  'Beckum': ['59269', '59269'],
#  'Bedburg': ['50181', '50181'],
#  'Bedburg-Hau': ['47551', '47551'],
#  'Bedesbach': ['66885', '66885'],
#  'Beedenbostel': ['29355', '29355'],
#  'Beelen': ['48361', '48361'],
#  'Beelitz': ['14547', '14547'],
#  'Beendorf': ['39343', '39343'],
#  'Beerfelden': ['64743', '64743'],
#  'Beeskow': ['15848', '15848'],
#  'Beesten': ['49832', '49832'],
#  'Beetzendorf': ['38489', '38489'],
#  'Beetzsee': ['14778', '14778'],
#  'Beetzseeheide': ['14778', '14778'],
#  'Beggerow': ['17111', '17111'],
#  'Behlendorf': ['23919', '23919'],
#  'Behrendorf': ['25850', '25850'],
#  'Behrenhoff': ['17498', '17498'],
#  'Behren-Lübchin': ['17179', '17179'],
#  'Behrensdorf': ['24321', '24321'],
#  'Beichlingen': ['99625', '99625'],
#  'Beidenfleth': ['25573', '25573'],
#  'Beiersdorf': ['2736', '2736'],
#  'Beiersdorf-Freudenberg': ['16259', '16259'],
#  'Beierstedt': ['38382', '38382'],
#  'Beilingen': ['54662', '54662'],
#  'Beilngries': ['92339', '92339'],
#  'Beilrode': ['4886', '4886'],
#  'Beilstein': ['71543', '71543', '71717', '56814'],
#  'Beimerstetten': ['89179', '89179'],
#  'Beindersheim': ['67259', '67259'],
#  'Beinerstadt': ['98660', '98660'],
#  'Beinhausen': ['54552', '54552'],
#  'Bekdorf': ['25554', '25554'],
#  'Bekmünde': ['25524', '25524'],
#  'Bekond': ['54340', '54340'],
#  'Belau': ['24601', '24601'],
#  'Beldorf': ['25557', '25557', '25767'],
#  'Belg': ['56858', '56858'],
#  'Belgern-Schildau': ['4874', '4874', '4889'],
#  'Belgershain': ['4683', '4683'],
#  'Belgweiler': ['55469', '55469'],
#  'Bell': ['56745', '56745'],
#  'Bellenberg': ['89287', '89287'],
#  'Bellheim': ['76756', '76756'],
#  'Bell (Hunsrück)': ['56288', '56288'],
#  'Bellingen': ['56459', '56459'],
#  'Bellstedt': ['99713', '99713'],
#  'Belm': ['49191', '49191'],
#  'Belrieth': ['98617', '98617'],
#  'Belsch': ['19230', '19230'],
#  'Beltheim': ['56290', '56290'],
#  'Belum': ['21785', '21785'],
#  'Bempflingen': ['72658', '72658'],
#  'Bendestorf': ['21227', '21227'],
#  'Bendfeld': ['24217', '24217'],
#  'Bendorf': ['56170', '56170', '25557'],
#  'Benediktbeuern': ['83671', '83671'],
#  'Bengel': ['54538', '54538'],
#  'Bengerstorf': ['19258', '19258'],
#  'Benitz': ['18258', '18258'],
#  'Benndorf': ['6308', '6308'],
#  'Bennewitz': ['4828', '4828'],
#  'Bennhausen': ['67808', '67808'],
#  'Benningen': ['87734', '87734'],
#  'Benningen am Neckar': ['71726', '71726'],
#  'Bensdorf': ['14789', '14789'],
#  'Benshausen': ['98554', '98554'],
#  'Bensheim': ['64625', '64625'],
#  'Bentwisch': ['18182', '18182'],
#  'Bentzin': ['17129', '17129'],
#  'Benz': ['17429', '17429', '23970'],
#  'Benzweiler': ['55494', '55494'],
#  'Beratzhausen': ['93176', '93176'],
#  'Berching': ['92334', '92334'],
#  'Berchtesgaden': ['83471', '83471'],
#  'Bereborn': ['56769', '56769'],
#  'Berenbach': ['56766', '56766'],
#  'Berg': ['56357', '56357', '82335', '95180', '53505', '88276'],
#  'Berga': ['6536', '6536'],
#  'Berga/Elster': ['7980', '7980'],
#  'Bergatreute': ['88368', '88368'],
#  'Berg bei Neumarkt in der Oberpfalz': ['92348', '92348'],
#  'Berge': ['19348', '19348', '49626'],
#  'Bergen': ['8239', '8239', '83346', '91790', '55608', '29303'],
#  'Bergen an der Dumme': ['29468', '29468'],
#  'Bergen auf Rügen': ['18528', '18528'],
#  'Bergenhausen': ['55469', '55469'],
#  'Bergenhusen': ['24861', '24861'],
#  'Bergewöhrden': ['25779', '25779'],
#  'Bergfeld': ['38467', '38467'],
#  'Berghaupten': ['77791', '77791'],
#  'Berghausen': ['56368', '56368'],
#  'Bergheim': ['50126', '50126', '50127', '50129', '86673'],
#  'Bergholz': ['17321', '17321'],
#  'Berghülen': ['89180', '89180'],
#  'Berg im Gau': ['86562', '86562'],
#  'Bergisch Gladbach': ['51427', '51427', '51429', '51465', '51467', '51469'],
#  'Bergkamen': ['59192', '59192'],
#  'Bergkirchen': ['85232', '85232'],
#  'Berglangenbach': ['55776', '55776'],
#  'Berglen': ['73663', '73663'],
#  'Berglern': ['85459', '85459'],
#  'Berglicht': ['54426', '54426'],
#  'Bergneustadt': ['51702', '51702'],
#  'Berg (Pfalz)': ['76768', '76768'],
#  'Bergrheinfeld': ['97493', '97493'],
#  'Bergtheim': ['97241', '97241'],
#  'Bergweiler': ['54518', '54518'],
#  'Beringstedt': ['25575', '25575'],
#  'Berkatal': ['37297', '37297'],
#  'Berka vor dem Hainich': ['99826', '99826'],
#  'Berka/Werra': ['99837', '99837'],
#  'Berkenbrück': ['15518', '15518'],
#  'Berkenthin': ['23919', '23919'],
#  'Berkheim': ['88450', '88450'],
#  'Berkholz-Meyenburg': ['16306', '16306'],
#  'Berkoth': ['54673', '54673'],
#  'Berlin': ['10115',
#   '10115',
#   '10117',
#   '10119',
#   '10178',
#   '10179',
#   '10243',
#   '10245',
#   '10247',
#   '10249',
#   '10315',
#   '10317',
#   '10318',
#   '10319',
#   '10365',
#   '10367',
#   '10369',
#   '10405',
#   '10407',
#   '10409',
#   '10435',
#   '10437',
#   '10439',
#   '10551',
#   '10553',
#   '10555',
#   '10557',
#   '10559',
#   '10585',
#   '10587',
#   '10589',
#   '10623',
#   '10625',
#   '10627',
#   '10629',
#   '10707',
#   '10709',
#   '10711',
#   '10713',
#   '10715',
#   '10717',
#   '10719',
#   '10777',
#   '10779',
#   '10781',
#   '10783',
#   '10785',
#   '10787',
#   '10789',
#   '10823',
#   '10825',
#   '10827',
#   '10829',
#   '10961',
#   '10963',
#   '10965',
#   '10967',
#   '10969',
#   '10997',
#   '10999',
#   '12043',
#   '12045',
#   '12047',
#   '12049',
#   '12051',
#   '12053',
#   '12055',
#   '12057',
#   '12059',
#   '12099',
#   '12101',
#   '12103',
#   '12105',
#   '12107',
#   '12109',
#   '12157',
#   '12159',
#   '12161',
#   '12163',
#   '12165',
#   '12167',
#   '12169',
#   '12203',
#   '12205',
#   '12207',
#   '12209',
#   '12247',
#   '12249',
#   '12277',
#   '12279',
#   '12305',
#   '12307',
#   '12309',
#   '12347',
#   '12349',
#   '12351',
#   '12353',
#   '12355',
#   '12357',
#   '12359',
#   '12435',
#   '12437',
#   '12439',
#   '12459',
#   '12487',
#   '12489',
#   '12524',
#   '12526',
#   '12527',
#   '12555',
#   '12557',
#   '12559',
#   '12587',
#   '12589',
#   '12619',
#   '12621',
#   '12623',
#   '12627',
#   '12629',
#   '12679',
#   '12681',
#   '12683',
#   '12685',
#   '12687',
#   '12689',
#   '13051',
#   '13053',
#   '13055',
#   '13057',
#   '13059',
#   '13086',
#   '13088',
#   '13089',
#   '13125',
#   '13127',
#   '13129',
#   '13156',
#   '13158',
#   '13159',
#   '13187',
#   '13189',
#   '13347',
#   '13349',
#   '13351',
#   '13353',
#   '13355',
#   '13357',
#   '13359',
#   '13403',
#   '13405',
#   '13407',
#   '13409',
#   '13435',
#   '13437',
#   '13439',
#   '13465',
#   '13467',
#   '13469',
#   '13503',
#   '13505',
#   '13507',
#   '13509',
#   '13581',
#   '13583',
#   '13585',
#   '13587',
#   '13589',
#   '13591',
#   '13593',
#   '13595',
#   '13597',
#   '13599',
#   '13627',
#   '13629',
#   '14050',
#   '14052',
#   '14053',
#   '14055',
#   '14057',
#   '14059',
#   '14089',
#   '14109',
#   '14129',
#   '14163',
#   '14165',
#   '14167',
#   '14169',
#   '14193',
#   '14195',
#   '14197',
#   '14199'],
#  'Berlingen': ['54570', '54570'],
#  'Berlingerode': ['37339', '37339'],
#  'Berlstedt': ['99439', '99439'],
#  'Bermatingen': ['88697', '88697'],
#  'Bermbach': ['98587', '98587'],
#  'Bermel': ['56729', '56729'],
#  'Bermersheim': ['67593', '67593'],
#  'Bermersheim vor der Höhe': ['55234', '55234'],
#  'Bernau': ['16321', '16321'],
#  'Bernau am Chiemsee': ['83233', '83233'],
#  'Bernau im Schwarzwald': ['79872', '79872'],
#  'Bernbeuren': ['86975', '86975'],
#  'Bernburg': ['6406', '6406'],
#  'Berndorf': ['54578', '54578'],
#  'Berndroth': ['56370', '56370'],
#  'Berne': ['27804', '27804'],
#  'Berngau': ['92361', '92361'],
#  'Bernhardswald': ['93170', '93170'],
#  'Bernitt': ['18246', '18246', '18249'],
#  'Bernkastel-Kues': ['54470', '54470', '54492'],
#  'Bernried': ['94505', '94505'],
#  'Bernried am Starnberger See': ['82347', '82347'],
#  'Bernsdorf': ['9337', '9337', '2994'],
#  'Bernstadt': ['89182', '89182'],
#  'Bernstadt auf dem Eigen': ['2748', '2748'],
#  'Bernstorf': ['23936', '23936'],
#  'Bernterode': ['37308', '37308'],
#  'Berod bei Hachenburg': ['57614', '57614'],
#  'Berod bei Wallmerod': ['56414', '56414'],
#  'Berscheid': ['54673', '54673'],
#  'Berschweiler bei Baumholder': ['55777', '55777'],
#  'Berschweiler bei Kirn': ['55608', '55608'],
#  'Bersenbrück': ['49593', '49593'],
#  'Bersteland': ['15910', '15910'],
#  'Bertsdorf-Hörnitz': ['2763', '2763'],
#  'Berumbur': ['26524', '26524'],
#  'Berzhahn': ['56459', '56459'],
#  'Berzhausen': ['57632', '57632'],
#  'Bescheid': ['54413', '54413'],
#  'Beschendorf': ['23738', '23738'],
#  'Besdorf': ['25584', '25584'],
#  'Beselich': ['65614', '65614'],
#  'Besenthal': ['23899', '23899'],
#  'Beseritz': ['17039', '17039'],
#  'Besigheim': ['74354', '74354'],
#  'Besitz': ['19258', '19258'],
#  'Bessenbach': ['63856', '63856'],
#  'Bestensee': ['15741', '15741'],
#  'Bestwig': ['59909', '59909'],
#  'Bethenhausen': ['7554', '7554'],
#  'Betteldorf': ['54570', '54570'],
#  'Bettendorf': ['56355', '56355'],
#  'Bettenfeld': ['54533', '54533'],
#  'Bettingen': ['54646', '54646'],
#  'Betzdorf': ['57518', '57518'],
#  'Betzendorf': ['21386', '21386'],
#  'Betzenstein': ['91282', '91282'],
#  'Betzenweiler': ['88422', '88422'],
#  'Betzigau': ['87488', '87488'],
#  'Beulich': ['56283', '56283'],
#  'Beuren': ['56825', '56825', '72660'],
#  'Beuren (Hochwald)': ['54413', '54413'],
#  'Beuron': ['88631', '88631'],
#  'Beutelsbach': ['94501', '94501'],
#  'Bevern': ['25355', '25355', '37639'],
#  'Beverstedt': ['27616', '27616'],
#  'Beverungen': ['37688', '37688'],
#  'Bexbach': ['66450', '66450'],
#  'Biberach': ['77781', '77781'],
#  'Biberach an der Riß': ['88400', '88400'],
#  'Biberbach': ['86485', '86485'],
#  'Bibertal': ['89346', '89346'],
#  'Biblis': ['68647', '68647'],
#  'Bibow': ['19417', '19417'],
#  'Bibra': ['7768', '7768'],
#  'Biburg': ['93354', '93354'],
#  'Bichl': ['83673', '83673'],
#  'Bickenbach': ['64404', '64404', '56291'],
#  'Bickendorf': ['54636', '54636'],
#  'Bidingen': ['87651', '87651'],
#  'Biebelnheim': ['55234', '55234'],
#  'Biebelried': ['97318', '97318'],
#  'Biebelsheim': ['55546', '55546'],
#  'Bieberehren': ['97243', '97243'],
#  'Biebergemünd': ['63599', '63599'],
#  'Biebern': ['55471', '55471'],
#  'Biebertal': ['35444', '35444'],
#  'Biebesheim': ['64584', '64584'],
#  'Biebrich': ['56370', '56370'],
#  'Biedenkopf': ['35216', '35216'],
#  'Biederbach': ['79215', '79215'],
#  'Biederitz': ['39175', '39175'],
#  'Biedershausen': ['66917', '66917'],
#  'Biedesheim': ['67308', '67308'],
#  'Bielefeld': ['33602',
#   '33602',
#   '33604',
#   '33605',
#   '33607',
#   '33609',
#   '33611',
#   '33613',
#   '33615',
#   '33617',
#   '33619',
#   '33647',
#   '33649',
#   '33659',
#   '33689',
#   '33699',
#   '33719',
#   '33729',
#   '33739'],
#  'Biendorf': ['18230', '18230', '18233'],
#  'Bienenbüttel': ['29553', '29553'],
#  'Bienstädt': ['99100', '99100'],
#  'Biersdorf am See': ['54636', '54636'],
#  'Biesdorf': ['54675', '54675'],
#  'Biesenthal': ['16359', '16359'],
#  'Biessenhofen': ['87640', '87640'],
#  'Bietigheim': ['76467', '76467'],
#  'Bietigheim-Bissingen': ['74321', '74321'],
#  'Bilkheim': ['56414', '56414'],
#  'Billerbeck': ['48727', '48727'],
#  'Billigheim': ['74842', '74842'],
#  'Billigheim-Ingenheim': ['76831', '76831'],
#  'Bilsen': ['25485', '25485'],
#  'Bilshausen': ['37434', '37434'],
#  'Bilzingsleben': ['6578', '6578'],
#  'Bimöhlen': ['24576', '24576'],
#  'Binau': ['74862', '74862'],
#  'Bindlach': ['95463', '95463'],
#  'Bingen': ['72511', '72511'],
#  'Bingen am Rhein': ['55411', '55411'],
#  'Binnen': ['31619', '31619'],
#  'Binningen': ['56754', '56754'],
#  'Binsfeld': ['54518', '54518'],
#  'Binswangen': ['86637', '86637'],
#  'Binz': ['18609', '18609'],
#  'Binzen': ['79589', '79589'],
#  'Bippen': ['49626', '49626'],
#  'Birenbach': ['73102', '73102'],
#  'Birgel': ['54587', '54587'],
#  'Birgland': ['92262', '92262'],
#  'Birkenau': ['69488', '69488'],
#  'Birkenbeul': ['57589', '57589'],
#  'Birkenfeld': ['75217', '75217', '97834', '55765'],
#  'Birkenfelde': ['37318', '37318'],
#  'Birkenheide': ['67134', '67134'],
#  'Birken-Honigsessen': ['57587', '57587'],
#  'Birkenhördt': ['76889', '76889'],
#  'Birkenhügel': ['7366', '7366'],
#  'Birkenwerder': ['16547', '16547'],
#  'Birkheim': ['56291', '56291'],
#  'Birkweiler': ['76831', '76831'],
#  'Birlenbach': ['65626', '65626'],
#  'Birnbach': ['57612', '57612'],
#  'Birresborn': ['54574', '54574'],
#  'Birstein': ['63633', '63633'],
#  'Birtlingen': ['54634', '54634'],
#  'Birx': ['98634', '98634'],
#  'Bischberg': ['96120', '96120'],
#  'Bischbrunn': ['97836', '97836', '97852'],
#  'Bischheim': ['67294', '67294'],
#  'Bischoffen': ['35649', '35649'],
#  'Bischofrod': ['98553', '98553'],
#  'Bischofroda': ['99826', '99826'],
#  'Bischofsgrün': ['95493', '95493'],
#  'Bischofsheim': ['65474', '65474'],
#  'Bischofsheim a.d.Rhön': ['97653', '97653'],
#  'Bischofsmais': ['94253', '94253'],
#  'Bischofswerda': ['1877', '1877'],
#  'Bischofswiesen': ['83483', '83483'],
#  'Bischweier': ['76476', '76476'],
#  'Bisingen': ['72406', '72406'],
#  'Bismark (Altmark)': ['39579', '39579', '39599', '39606', '39624', '39629'],
#  'Bispingen': ['29646', '29646'],
#  'Bissee': ['24582', '24582'],
#  'Bissendorf': ['49143', '49143'],
#  'Bissersheim': ['67281', '67281'],
#  'Bissingen': ['86657', '86657'],
#  'Bissingen an der Teck': ['73266', '73266'],
#  'Bisterschied': ['67806', '67806'],
#  'Bitburg': ['54634', '54634'],
#  'Bitterfeld-Wolfen': ['6749', '6749', '6766', '6803', '6808'],
#  'Bitz': ['72475', '72475'],
#  'Bitzen': ['57539', '57539'],
#  ...}

# %% [markdown]
# # write a program that recoginzes the postal code or not
# https://en.wikipedia.org/wiki/Postcodes_in_the_United_Kingdom#:~:text=The%20outward%20code%20includes%20the,%2C%20and%20%22L1%208JQ%22.
#
# eg:
# ```
# N1 9GU matched!
# E98 1TT matched!
# TIM E22 is not a valid postcode!
# A B1 A22 is not a valid postcode!
# EC2N 2DB matched!

# %%
codes = ["SW1A 0AA", # House of Commons
                "BS40 5AA ", # bristol
                "CB6 1AA",#cambridge
                "CB2 1TN",#cambdrige uni
                 "SW1A 1AA", # Buckingham Palace
                 "SW1A 2AA", # Downing Street
                 "DH98 1BT", # British Telecom
                 "OX1 2JD",#oxford
                 "N1 9GU", # Guardian Newspaper
                 "E98 1TT", # The Times
                 "TIM E22", # a fake postcode
                 "A B1 A22", # not a valid postcode
                 "EC2N 2DB", # Deutsche Bank
                 "SE9 2UG", # University of Greenwhich
                 "N1 0UY", # Islington, London
                 "EC1V 8DS", # Clerkenwell, London
                 "WC1X 9DT", # WC1X 9DT
                 "B42 1LG", # Birmingham
                 "B28 9AD", # Birmingham
                 "W12 7RJ", # London, BBC News Centre
                 "BBC 017" ,# a fake postcode
                 "JAM 001", #fake
                 "BD7 1DP",#bradford uni
                 "JCK 4DA", #not valid
                 
                ]

# %%
checking = lambda x: "matched" if re.findall(r"^[A-Z]{1,2}[0-9][A-Z0-9]? ?[0-9][A-Z]{2}$", x)!=[] else "not a valid postcode"
list(map(checking,codes))
# Out:
# ['matched',
#  'not a valid postcode',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'not a valid postcode',
#  'not a valid postcode',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'matched',
#  'not a valid postcode',
#  'not a valid postcode',
#  'matched',
#  'not a valid postcode']

# %%
# Sushree code
for i in codes:
    if re.search(r"\b[0-9][A-Z][A-Z]",i):
        if re.search(r"\b[A-Z]1|\b[A-Z].\d[A-Z0-9]|\b[A-Z]\d.|\b[A-Z].\d",i):
            print(f"{i} is matched code.")
        else:
            print(f"{i} is not a valid code.")
    else:
        if re.search(r"\b[A-Z][A-Z].",i):
            print(f"{i} is a fake code.")
        else:
            print(f"{i} is not a valid postcode.")
# Out:
# SW1A 0AA is matched code.
# BS40 5AA  is matched code.
# CB6 1AA is matched code.
# CB2 1TN is matched code.
# SW1A 1AA is matched code.
# SW1A 2AA is matched code.
# DH98 1BT is matched code.
# OX1 2JD is matched code.
# N1 9GU is matched code.
# E98 1TT is matched code.
# TIM E22 is a fake code.
# A B1 A22 is not a valid postcode.
# EC2N 2DB is matched code.
# SE9 2UG is matched code.
# N1 0UY is matched code.
# EC1V 8DS is matched code.
# WC1X 9DT is matched code.
# B42 1LG is matched code.
# B28 9AD is matched code.
# W12 7RJ is matched code.
# BBC 017 is a fake code.
# JAM 001 is a fake code.
# BD7 1DP is matched code.
# JCK 4DA is not a valid code.

# %% [markdown]
# # write a expression to get first name , last name and position
#
# hint:you can use re.split

# %%
lines = ["surname: Trump, prename: Donald, profession: ex.president", 
"surname: Merkel, prename: Angela, profession: chancellor",
"surname: Biden , prename: joe , profession: president",
"surname: musk prename: elon, profession: enturperuner"]

# %%
capture_name_pos = lambda x : re.split("surname:\s(\w+)\s*,*\sprename:\s(\w+)\s*,*\sprofession:\s(\w*\.*\w*)", x)
extracted = list(map(capture_name_pos, lines))
dict_names_pos= {'first_name':[], 'last_name':[], 'position':[]}
for _,last,first,pos,_  in extracted:
    dict_names_pos['first_name'].append(first)
    dict_names_pos['last_name'].append(last)
    dict_names_pos['position'].append(pos)
print(dict_names_pos)
# Out:
# {'first_name': ['Donald', 'Angela', 'joe', 'elon'], 'last_name': ['Trump', 'Merkel', 'Biden', 'musk'], 'position': ['ex.president', 'chancellor', 'president', 'enturperuner']}

# %%
# Niguen sol
for i in lines:
    #print(i)
    result=re.split(r"\s?'?,?\s?\w*:\s+", i)
    print(result[1:])
# Out:
# ['Trump', 'Donald', 'ex.president']
# ['Merkel', 'Angela', 'chancellor']
# ['Biden', 'joe', 'president']
# ['musk', 'elon', 'enturperuner']

# %% [markdown]
# # from a given text write a expression to get the
# ```
# 1289,T83456
#
# 1289,Z22334
#
# 1205,T10032
#
# 1205,B77301
#
# 1205,T10786
#
# 1205,C77502
#
# 1410,K34001
#
# 1410,T98987
# ```

# %%
text="""customer-id 1111
T93923
customer-id 1111
customer-id 1223
T10321
B71313
customer-id 1223
customer-id 1410
K34001
T98987
customer-id 1410
customer-id 1223
T10786
C77502
customer-id 1225
customer-id 1289
Z22334
customer-id 1289"""

# %%
re1 = re.findall("([A-Z]\d{5})\ncustomer-id\s(\d{4})", text)
re1 = [(i,j) for j,i in re1]
re1.extend(re.findall("(\d{4})\n([A-Z]\d{5})", text))
for i,j in sorted(re1):
    print(f"{i},{j}")
# Out:
# 1111,T93923
# 1111,T93923
# 1223,B71313
# 1223,T10321
# 1223,T10786
# 1225,C77502
# 1289,Z22334
# 1289,Z22334
# 1410,K34001
# 1410,T98987

# %% [markdown]
# *****************************************__The End__********************************************
